# %%
'''

@Author: Vighnesh Harish Bilgi
@Date: 2022-12-09
@Last Modified by: Vighnesh Harish Bilgi
@Last Modified time: 2022-12-09
@Title : Data Modelling - 3 : SQL analysis on Sakila(DVD Rental) database

'''
# Out:
# '\n\n@Author: Vighnesh Harish Bilgi\n@Date: 2022-12-09\n@Last Modified by: Vighnesh Harish Bilgi\n@Last Modified time: 2022-12-09\n@Title : Data Modelling - 3\n\n'

# %%
import mysql.connector
import pandas as pd
import os

# %%
sql_password = os.environ.get("sql_password")

# %% [markdown]
# ### Custom functions to connect to the mysql server and iterate the cursor

# %%
def iterate_cursor(db_cursor):
    """
    Description:
        Take MySQLCursor argument from parameter "db_cursor" and iterate and print the selected records with its column name 
        (i.e. a SELECT or SHOW command must be called before iterate_cursor() is called).
    Parameter:
        MySQLCursor db_cursor
    Return:
        No values returned.
    """
    print(db_cursor.column_names)
    for db in db_cursor:
        print(db)

def connect_to_sql():
    """
    Description:
        To setup connection to MySQL Server, pass hostname , user and password as arguments to parameters "host","user" and "passwd" of connect() respectively.
        connect() is method from module "mysql.connector". Once the connection is set. Return it.
    Parameter:
        No parameters.
    Return:
        MYSQLConnection db_connection
    """

    db_connection = mysql.connector.connect(
    host= "localhost",
    user= "root",
    passwd= sql_password
    )

    return db_connection

# %% [markdown]
# ### Call fuction to connect to mysql cursor and get a cursor to execute queries

# %%
db_connection = connect_to_sql()
db_cursor = db_connection.cursor(buffered=True)

# %% [markdown]
# ### Run query to show databases

# %%
db_cursor.execute("show databases")
iterate_cursor(db_cursor)
# Out:
# ('Database',)
# ('accounts',)
# ('information_schema',)
# ('myfirstdb',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)

# %% [markdown]
# ### Run query to use 'sakila' database

# %%
db_cursor.execute("use sakila")

# %% [markdown]
# ### Run query to find number of customers from 'customer' table

# %%
db_cursor.execute("select count(*) as no_of_customers from customer")
iterate_cursor(db_cursor)
# Out:
# ('no_of_customers',)
# (599,)

# %% [markdown]
# ### Run query to find number of stores from 'store' table

# %%
db_cursor.execute("select count(*) as no_of_stores from store")
iterate_cursor(db_cursor)
# Out:
# ('no_of_stores',)
# (2,)

# %% [markdown]
# ### Run query to find earlies and latest payment date

# %%
db_cursor.execute("select min(payment_date) as earliest_payment_date, max(payment_date) as latest_payment_date from payment")
iterate_cursor(db_cursor)
# Out:
# ('earliest_payment_date', 'latest_payment_date')
# (datetime.datetime(2005, 5, 24, 22, 53, 30), datetime.datetime(2006, 2, 14, 15, 16, 3))

# %% [markdown]
# ### Run query to find revenues made from films

# %%
db_cursor.execute("""SELECT f.title , sum(p.amount) as revenue from payment as p
JOIN rental r ON p.rental_id = r.rental_id
JOIN inventory i ON r.inventory_id = i.inventory_id
JOIN film f ON i.film_id = f.film_id
GROUP BY f.title
ORDER BY revenue desc""")
iterate_cursor(db_cursor)
# Out:
# ('title', 'revenue')
# ('TELEGRAPH VOYAGE', Decimal('231.73'))
# ('WIFE TURN', Decimal('223.69'))
# ('ZORRO ARK', Decimal('214.69'))
# ('GOODFELLAS SALUTE', Decimal('209.69'))
# ('SATURDAY LAMBS', Decimal('204.72'))
# ('TITANS JERK', Decimal('201.71'))
# ('TORQUE BOUND', Decimal('198.72'))
# ('HARRY IDAHO', Decimal('195.70'))
# ('INNOCENT USUAL', Decimal('191.74'))
# ('HUSTLER PARTY', Decimal('190.78'))
# ('PELICAN COMFORTS', Decimal('188.74'))
# ('CAT CONEHEADS', Decimal('181.70'))
# ('ENEMY ODDS', Decimal('180.71'))
# ('BUCKET BROTHERHOOD', Decimal('180.66'))
# ('RANGE MOONWALKER', Decimal('179.73'))
# ('MASSACRE USUAL', Decimal('179.70'))
# ('VIDEOTAPE ARSENIC', Decimal('178.71'))
# ('DOGMA FAMILY', Decimal('178.70'))
# ('APACHE DIVINE', Decimal('178.69'))
# ('VELVET TERMINATOR', Decimal('177.74'))
# ('DORADO NOTTING', Decimal('176.73'))
# ('FOOL MOCKINGBIRD', Decimal('175.77'))
# ('WITCHES PANIC', Decimal('173.70'))
# ('CLOSER BANG', Decimal('172.72'))
# ('SCALAWAG DUCK', Decimal('172.68'))
# ('ROSES TREASURE', Decimal('171.72'))
# ('SUNRISE LEAGUE', Decimal('170.76'))
# ('SHOW LORD', Decimal('170.75'))
# ('NIGHTMARE CHILL', Decimal('169.75'))
# ('SCORPION APOLLO', Decimal('168.77'))
# ('AMERICAN CIRCUS', Decimal('167.78'))
# ('CONFIDENTIAL INTERVIEW', Decimal('164.71'))
# ('MAIDEN HOME', Decimal('163.76'))
# ('SEATTLE EXPECATIONS', Decimal('163.75'))
# ('WORKING MICROCOSMOS', Decimal('163.75'))
# ('BOOGIE AMELIE', Decimal('163.70'))
# ('STING PERSONAL', Decimal('159.79'))
# ('LOLA AGENT', Decimal('159.76'))
# ('BACKLASH UNDEFEATED', Decimal('158.81'))
# ('MIDSUMMER GROUNDHOG', Decimal('156.78'))
# ('TITANIC BOONDOCK', Decimal('154.77'))
# ('STAGECOACH ARMAGEDDON', Decimal('154.74'))
# ('MINE TITANS', Decimal('153.81'))
# ('PITY BOUND', Decimal('153.74'))
# ('SECRETS PARADISE', Decimal('152.80'))
# ('EAGLES PANKY', Decimal('152.78'))
# ('HEAD STRANGER', Decimal('152.78'))
# ('WHISPERER GIANT', Decimal('151.78'))
# ('EASY GLADIATOR', Decimal('150.77'))
# ('MINDS TRUMAN', Decimal('149.80'))
# ('FELLOWSHIP AUTUMN', Decimal('149.74'))
# ('WONDERLAND CHRISTMAS', Decimal('148.78'))
# ('STREETCAR INTENTIONS', Decimal('148.75'))
# ('KISSING DOLLS', Decimal('147.80'))
# ('SUIT WALLS', Decimal('147.79'))
# ('TRADING PINOCCHIO', Decimal('147.75'))
# ('LIES TREATMENT', Decimal('147.73'))
# ('ATTRACTION NEWTON', Decimal('146.76'))
# ('FORRESTER COMANCHEROS', Decimal('146.73'))
# ('MOVIE SHAKESPEARE', Decimal('145.74'))
# ('TRIP NEWTON', Decimal('145.72'))
# ('GARDEN ISLAND', Decimal('144.80'))
# ('DURHAM PANKY', Decimal('144.74'))
# ('PRINCESS GIANT', Decimal('142.74'))
# ('CALENDAR GUNFIGHT', Decimal('141.79'))
# ('MOONSHINE CABIN', Decimal('141.79'))
# ('TOURIST PELICAN', Decimal('141.78'))
# ('STEEL SANTA', Decimal('141.77'))
# ('DRIFTER COMMANDMENTS', Decimal('141.76'))
# ('CHANCE RESURRECTION', Decimal('141.73'))
# ('FLAMINGOS CONNECTICUT', Decimal('139.77'))
# ('FIDELITY DEVIL', Decimal('138.79'))
# ('CENTER DINOSAUR', Decimal('137.76'))
# ('COMA HEAD', Decimal('137.74'))
# ('QUEEN LUKE', Decimal('136.78'))
# ('NAME DETECTIVE', Decimal('136.77'))
# ('CONEHEADS SMOOCHY', Decimal('136.75'))
# ('GLEAMING JAWBREAKER', Decimal('136.70'))
# ('PULP BEVERLY', Decimal('136.70'))
# ('YENTL IDAHO', Decimal('135.77'))
# ('FLINTSTONES HAPPINESS', Decimal('134.83'))
# ('WHALE BIKINI', Decimal('134.82'))
# ('HUNCHBACK IMPOSSIBLE', Decimal('134.80'))
# ('DETAILS PACKER', Decimal('133.81'))
# ('PINOCCHIO SIMON', Decimal('133.80'))
# ('SUSPECTS QUILLS', Decimal('133.70'))
# ('NETWORK PEAK', Decimal('133.69'))
# ('HEARTBREAKERS BRIGHT', Decimal('132.80'))
# ('BEAUTY GREASE', Decimal('132.78'))
# ('KISS GLORY', Decimal('132.78'))
# ('LIAISONS SWEET', Decimal('131.78'))
# ('ALADDIN CALENDAR', Decimal('131.77'))
# ('SLEEPING SUSPECTS', Decimal('131.76'))
# ('METROPOLIS COMA', Decimal('131.74'))
# ('BINGO TALENTED', Decimal('131.71'))
# ('ROAD ROXANNE', Decimal('130.81'))
# ('MILLION ACE', Decimal('130.80'))
# ('RIDGEMONT SUBMARINE', Decimal('130.68'))
# ('SATISFACTION CONFIDENTIAL', Decimal('129.83'))
# ('HEAVYWEIGHTS BEAST', Decimal('129.77'))
# ('DAWN POND', Decimal('128.82'))
# ('INTERVIEW LIAISONS', Decimal('128.80'))
# ('CAUSE DATE', Decimal('128.79'))
# ('CANDLES GRAPES', Decimal('128.77'))
# ('FORWARD TEMPLE', Decimal('128.68'))
# ('TEEN APOLLO', Decimal('127.83'))
# ('SOMETHING DUCK', Decimal('127.81'))
# ('SNATCH SLIPPER', Decimal('127.78'))
# ('FALCON VOLUME', Decimal('127.77'))
# ('TRAP GUYS', Decimal('126.84'))
# ('MISSION ZOOLANDER', Decimal('126.82'))
# ('AGENT TRUMAN', Decimal('126.79'))
# ('SABRINA MIDNIGHT', Decimal('126.79'))
# ('FREDDY STORM', Decimal('126.77'))
# ('STRANGERS GRAFFITI', Decimal('123.83'))
# ('DOORS PRESIDENT', Decimal('123.81'))
# ('MALTESE HOPE', Decimal('123.78'))
# ('BUTTERFLY CHOCOLAT', Decimal('123.70'))
# ('TIMBERLAND SKY', Decimal('123.69'))
# ('WATERFRONT DELIVERANCE', Decimal('121.83'))
# ('SLEEPLESS MONSOON', Decimal('121.80'))
# ('TRUMAN CRAZY', Decimal('121.77'))
# ('SCARFACE BANG', Decimal('120.82'))
# ('HIGH ENCINO', Decimal('120.78'))
# ('RAGE GAMES', Decimal('119.81'))
# ('GHOST GROUNDHOG', Decimal('119.79'))
# ('ANGELS LIFE', Decimal('119.78'))
# ('WASH HEAVENLY', Decimal('119.77'))
# ('LADY STAGE', Decimal('118.83'))
# ('DESERT POSEIDON', Decimal('118.81'))
# ('PHILADELPHIA WIFE', Decimal('118.78'))
# ('VIRTUAL SPOILERS', Decimal('117.86'))
# ('THIEF PELICAN', Decimal('117.81'))
# ('BROOKLYN DESERT', Decimal('116.79'))
# ('SECRET GROUNDHOG', Decimal('116.79'))
# ('KNOCK WARLOCK', Decimal('116.76'))
# ('HANKY OCTOBER', Decimal('116.74'))
# ('ROCKETEER MOTHER', Decimal('116.67'))
# ('GALAXY SWEETHEARTS', Decimal('115.82'))
# ('PREJUDICE OLEANDER', Decimal('115.80'))
# ('SPICE SORORITY', Decimal('115.80'))
# ('BEVERLY OUTLAW', Decimal('115.79'))
# ('DRIVING POLISH', Decimal('115.79'))
# ('CONVERSATION DOWNHILL', Decimal('114.83'))
# ('UNDEFEATED DALMATIONS', Decimal('114.79'))
# ('ARACHNOPHOBIA ROLLERCOASTER', Decimal('114.76'))
# ('IDOLS SNATCHERS', Decimal('114.70'))
# ('HANGING DEEP', Decimal('113.81'))
# ('REDEMPTION COMFORTS', Decimal('113.80'))
# ('OPEN AFRICAN', Decimal('113.79'))
# ('STRICTLY SCARFACE', Decimal('113.77'))
# ('SECRETARY ROUGE', Decimal('112.82'))
# ('HORN WORKING', Decimal('112.76'))
# ('CLUELESS BUCKET', Decimal('112.75'))
# ('GANGS PRIDE', Decimal('112.73'))
# ('BIRDS PERDITION', Decimal('111.82'))
# ('SWEDEN SHINING', Decimal('111.81'))
# ('MONEY HAROLD', Decimal('111.80'))
# ('FARGO GANDHI', Decimal('111.76'))
# ('PANKY SUBMARINE', Decimal('110.85'))
# ('DUDE BLINDNESS', Decimal('110.84'))
# ('EXPECATIONS NATURAL', Decimal('110.82'))
# ('CHASING FIGHT', Decimal('110.81'))
# ('REQUIEM TYCOON', Decimal('110.81'))
# ('REIGN GENTLEMEN', Decimal('110.80'))
# ('TOMORROW HUSTLER', Decimal('110.75'))
# ('GRIT CLOCKWORK', Decimal('110.68'))
# ('DAY UNFAITHFUL', Decimal('109.86'))
# ('BREAKFAST GOLDFINGER', Decimal('109.83'))
# ('SHAWSHANK BUBBLE', Decimal('109.81'))
# ('JET NEIGHBORS', Decimal('109.80'))
# ('GREATEST NORTH', Decimal('109.71'))
# ('FISH OPUS', Decimal('108.75'))
# ('SAMURAI LION', Decimal('108.75'))
# ('COMMAND DARLING', Decimal('107.84'))
# ('ROCKY WAR', Decimal('107.84'))
# ('JERK PAYCHECK', Decimal('107.80'))
# ('BEAR GRACELAND', Decimal('107.78'))
# ('SOUTH WAIT', Decimal('107.78'))
# ('FATAL HAUNTED', Decimal('107.72'))
# ('CUPBOARD SINNERS', Decimal('106.77'))
# ('SALUTE APOLLO', Decimal('106.77'))
# ('GIANT TROOPERS', Decimal('106.72'))
# ('LEAGUE HELLFIGHTERS', Decimal('105.83'))
# ('SUGAR WONKA', Decimal('105.83'))
# ('GORGEOUS BINGO', Decimal('105.81'))
# ('PEAK FOREVER', Decimal('105.80'))
# ('EGG IGBY', Decimal('105.79'))
# ('ROBBERS JOON', Decimal('105.69'))
# ('WEST LION', Decimal('104.84'))
# ('STEPMOM DREAM', Decimal('104.80'))
# ('ARIZONA BANG', Decimal('104.79'))
# ('HYDE DOCTOR', Decimal('104.73'))
# ('TYCOON GATHERING', Decimal('103.88'))
# ('CORE SUIT', Decimal('103.82'))
# ('DRAGONFLY STRANGERS', Decimal('103.82'))
# ('METAL ARMAGEDDON', Decimal('103.75'))
# ('INVASION CYCLONE', Decimal('103.73'))
# ('ENGLISH BULWORTH', Decimal('103.70'))
# ('BILKO ANONYMOUS', Decimal('102.87'))
# ('CONFUSED CANDLES', Decimal('102.83'))
# ('FRENCH HOLIDAY', Decimal('102.83'))
# ('AIRPORT POLLOCK', Decimal('102.82'))
# ('GROUNDHOG UNCUT', Decimal('102.82'))
# ('PATTON INTERVIEW', Decimal('102.77'))
# ('ATTACKS HATE', Decimal('101.84'))
# ('PAYCHECK WAIT', Decimal('101.84'))
# ('RULES HUMAN', Decimal('101.84'))
# ('BROTHERHOOD BLANKET', Decimal('101.74'))
# ('CAMELOT VACATION', Decimal('101.73'))
# ('BEHAVIOR RUNAWAY', Decimal('100.87'))
# ('QUILLS BULL', Decimal('100.84'))
# ('POSEIDON FOREVER', Decimal('100.83'))
# ('ICE CROSSING', Decimal('100.76'))
# ('JASON TRAP', Decimal('100.76'))
# ('CONQUERER NUTS', Decimal('99.84'))
# ('MERMAID INSECTS', Decimal('99.84'))
# ('IGBY MAKER', Decimal('99.81'))
# ('SHOCK CABIN', Decimal('99.70'))
# ('HALL CASSIDY', Decimal('98.84'))
# ('PICKUP DRIVING', Decimal('98.84'))
# ('BIKINI BORROWERS', Decimal('98.83'))
# ('HANOVER GALAXY', Decimal('98.83'))
# ('JERICHO MULAN', Decimal('98.83'))
# ('BALLOON HOMEWARD', Decimal('98.77'))
# ('SWEETHEARTS SUSPECTS', Decimal('98.71'))
# ('MARRIED GO', Decimal('98.70'))
# ('WIZARD COLDBLOODED', Decimal('97.84'))
# ('HELLFIGHTERS SIERRA', Decimal('97.80'))
# ('SEA VIRGIN', Decimal('97.78'))
# ('EXPENDABLE STALLION', Decimal('97.72'))
# ('DESTINY SATURDAY', Decimal('96.84'))
# ('CANDIDATE PERDITION', Decimal('96.81'))
# ('VACATION BOONDOCK', Decimal('96.79'))
# ('BARBARELLA STREETCAR', Decimal('96.75'))
# ('DEER VIRGINIAN', Decimal('96.72'))
# ('JUGGLER HARDLY', Decimal('96.68'))
# ('DAISY MENAGERIE', Decimal('95.84'))
# ('INCH JET', Decimal('95.82'))
# ('OZ LIAISONS', Decimal('95.76'))
# ('SEABISCUIT PUNK', Decimal('95.74'))
# ('MUSCLE BRIGHT', Decimal('95.70'))
# ('GOLD RIVER', Decimal('94.86'))
# ('SPY MILE', Decimal('94.73'))
# ('MODEL FISH', Decimal('93.85'))
# ('DYING MAKER', Decimal('93.83'))
# ('VIRGIN DAISY', Decimal('93.83'))
# ('DARN FORRESTER', Decimal('93.82'))
# ('COLOR PHILADELPHIA', Decimal('93.76'))
# ('WARDROBE PHANTOM', Decimal('93.73'))
# ('BRIGHT ENCOUNTERS', Decimal('92.87'))
# ('FLASH WARS', Decimal('92.87'))
# ('EDGE KISSING', Decimal('92.85'))
# ('PURE RUNNER', Decimal('92.84'))
# ('MUSKETEERS WAIT', Decimal('92.83'))
# ('SLEEPY JAPANESE', Decimal('92.80'))
# ('SILVERADO GOLDFINGER', Decimal('91.88'))
# ('BETRAYED REAR', Decimal('91.85'))
# ('SAGEBRUSH CLUELESS', Decimal('91.84'))
# ('SLACKER LIAISONS', Decimal('91.83'))
# ('AFFAIR PREJUDICE', Decimal('91.77'))
# ('HALF OUTFIELD', Decimal('91.75'))
# ('TELEMARK HEARTBREAKERS', Decimal('91.75'))
# ('BLACKOUT PRIVATE', Decimal('91.73'))
# ('CONNECTICUT TRAMP', Decimal('90.87'))
# ('CAMPUS REMEMBER', Decimal('90.81'))
# ('BASIC EASY', Decimal('90.79'))
# ('ALIEN CENTER', Decimal('90.78'))
# ('FLATLINERS KILLER', Decimal('90.78'))
# ('ELEPHANT TROJAN', Decimal('89.86'))
# ('CHICAGO NORTH', Decimal('89.84'))
# ('COLDBLOODED DARLING', Decimal('89.84'))
# ('DISTURBING SCARFACE', Decimal('89.74'))
# ('PITTSBURGH HUNCHBACK', Decimal('88.88'))
# ('MEMENTO ZOOLANDER', Decimal('88.87'))
# ('MOONWALKER FOOL', Decimal('88.87'))
# ('LOSER HUSTLER', Decimal('88.85'))
# ('PANTHER REDS', Decimal('88.85'))
# ('SUBMARINE BED', Decimal('88.85'))
# ('PLUTO OLEANDER', Decimal('88.84'))
# ('RUSH GOODFELLAS', Decimal('88.69'))
# ('CINCINATTI WHISPERER', Decimal('87.87'))
# ('HYSTERICAL GRAIL', Decimal('87.85'))
# ('FORREST SONS', Decimal('87.82'))
# ('VANISHING ROCKY', Decimal('87.82'))
# ('NORTHWEST POLISH', Decimal('87.80'))
# ('ATLANTIS CAUSE', Decimal('87.76'))
# ('HORROR REIGN', Decimal('87.73'))
# ('OPERATION OPERATION', Decimal('87.73'))
# ('SUPER WYOMING', Decimal('86.87'))
# ('JEEPERS WEDDING', Decimal('86.84'))
# ('LAWLESS VISION', Decimal('86.84'))
# ('WANDA CHAMBER', Decimal('86.84'))
# ('JEKYLL FROGMEN', Decimal('86.83'))
# ('STAR OPERATION', Decimal('86.79'))
# ('STRANGELOVE DESIRE', Decimal('86.76'))
# ('CHAMPION FLATLINERS', Decimal('85.87'))
# ('ANTHEM LUKE', Decimal('85.85'))
# ('STEERS ARMAGEDDON', Decimal('85.85'))
# ('HURRICANE AFFAIR', Decimal('85.76'))
# ('CLASH FREDDY', Decimal('85.75'))
# ('CONTACT ANONYMOUS', Decimal('85.74'))
# ('ISLAND EXORCIST', Decimal('85.74'))
# ('TRACY CIDER', Decimal('85.74'))
# ('AUTUMN CROW', Decimal('84.89'))
# ('RAGING AIRPLANE', Decimal('84.87'))
# ('PEACH INNOCENT', Decimal('84.85'))
# ('COMFORTS RUSH', Decimal('84.83'))
# ('BLUES INSTINCT', Decimal('84.79'))
# ('MURDER ANTITRUST', Decimal('84.77'))
# ('DOWNHILL ENOUGH', Decimal('84.75'))
# ('MALKOVICH PET', Decimal('84.74'))
# ('NONE SPIKING', Decimal('84.73'))
# ('CALIFORNIA BIRDS', Decimal('83.88'))
# ('DEVIL DESIRE', Decimal('83.85'))
# ('CAROL TEXAS', Decimal('83.82'))
# ('EYES DRIVING', Decimal('83.81'))
# ('FLYING HOOK', Decimal('83.80'))
# ('WAIT CIDER', Decimal('83.79'))
# ('OSCAR GOLD', Decimal('83.75'))
# ('DARKO DORADO', Decimal('82.89'))
# ('CREEPERS KANE', Decimal('82.86'))
# ('AIRPLANE SIERRA', Decimal('82.85'))
# ('HOLIDAY GAMES', Decimal('82.85'))
# ('CASABLANCA SUPER', Decimal('82.84'))
# ('WORDS HUNTER', Decimal('82.84'))
# ('NATIONAL STORY', Decimal('82.81'))
# ('UNBREAKABLE KARATE', Decimal('82.79'))
# ('SHAKESPEARE SADDLE', Decimal('82.78'))
# ('PATHS CONTROL', Decimal('81.90'))
# ('SWEET BROTHERHOOD', Decimal('81.85'))
# ('TROJAN TOMORROW', Decimal('81.80'))
# ('DREAM PICKUP', Decimal('81.78'))
# ('GENTLEMEN STAGE', Decimal('81.77'))
# ('GOLDFINGER SENSIBILITY', Decimal('81.76'))
# ('WEDDING APOLLO', Decimal('81.76'))
# ('LOSE INCH', Decimal('81.73'))
# ('GRAFFITI LOVE', Decimal('81.70'))
# ('HOBBIT ALIEN', Decimal('81.69'))
# ('TIES HUNGER', Decimal('80.89'))
# ('DEEP CRUSADE', Decimal('80.86'))
# ('CHARADE DUFFEL', Decimal('80.85'))
# ('HUMAN GRAFFITI', Decimal('80.85'))
# ('IDAHO LOVE', Decimal('80.83'))
# ('ORIENT CLOSER', Decimal('80.83'))
# ('ESCAPE METROPOLIS', Decimal('80.75'))
# ('VAMPIRE WHALE', Decimal('79.88'))
# ('HOME PITY', Decimal('79.86'))
# ('BAKED CLEOPATRA', Decimal('79.84'))
# ('SONS INTERVIEW', Decimal('79.84'))
# ('FERRIS MOTHER', Decimal('79.83'))
# ('PARADISE SABRINA', Decimal('79.82'))
# ('TROUBLE DATE', Decimal('79.78'))
# ('OTHERS SOUP', Decimal('79.77'))
# ('JUMPING WRATH', Decimal('79.76'))
# ('WEREWOLF LOLA', Decimal('78.86'))
# ('INTENTIONS EMPIRE', Decimal('78.83'))
# ('BERETS AGENT', Decimal('78.78'))
# ('BOILED DARES', Decimal('77.85'))
# ('LONELY ELEPHANT', Decimal('77.85'))
# ('JACKET FRISCO', Decimal('77.82'))
# ('HARPER DYING', Decimal('77.80'))
# ('QUEST MUSSOLINI', Decimal('77.80'))
# ('CROSSROADS CASUALTIES', Decimal('77.79'))
# ('MALLRATS UNITED', Decimal('77.75'))
# ('BEAST HUNCHBACK', Decimal('76.89'))
# ('TUXEDO MILE', Decimal('76.87'))
# ('BLINDNESS GUN', Decimal('76.86'))
# ('GRINCH MASSAGE', Decimal('76.86'))
# ('IMAGE PRINCESS', Decimal('76.86'))
# ('MADISON TRAP', Decimal('76.85'))
# ('BADMAN DAWN', Decimal('76.79'))
# ('FROST HEAD', Decimal('76.70'))
# ('STRANGER STRANGERS', Decimal('75.89'))
# ('LIBERTY MAGNIFICENT', Decimal('75.88'))
# ('DADDY PITTSBURGH', Decimal('75.87'))
# ('CONFESSIONS MAGUIRE', Decimal('75.86'))
# ('HOLES BRANNIGAN', Decimal('75.86'))
# ('SEARCHERS WAIT', Decimal('75.86'))
# ('HOPE TOOTSIE', Decimal('75.82'))
# ('BIRCH ANTITRUST', Decimal('74.89'))
# ('BRANNIGAN SUNRISE', Decimal('74.88'))
# ('IMPOSSIBLE PREJUDICE', Decimal('74.86'))
# ('LUST LOCK', Decimal('74.82'))
# ('WEEKEND PERSONAL', Decimal('74.82'))
# ('HOMICIDE PEACH', Decimal('74.78'))
# ('HOUSE DYNAMITE', Decimal('74.77'))
# ('DOUBLE WRATH', Decimal('74.75'))
# ('THIN SAGEBRUSH', Decimal('73.89'))
# ('CHISUM BEHAVIOR', Decimal('73.87'))
# ('OUTLAW HANKY', Decimal('73.86'))
# ('WORST BANGER', Decimal('73.84'))
# ('ZOOLANDER FICTION', Decimal('73.83'))
# ('REMEMBER DIARY', Decimal('73.82'))
# ('FANTASIA PARK', Decimal('73.81'))
# ('INSIDER ARIZONA', Decimal('73.80'))
# ('DOOM DANCING', Decimal('73.79'))
# ('SINNERS ATLANTIS', Decimal('73.78'))
# ('MADNESS ATTACKS', Decimal('73.75'))
# ('CASUALTIES ENCINO', Decimal('72.91'))
# ('PAST SUICIDES', Decimal('72.87'))
# ('WYOMING STORM', Decimal('72.87'))
# ('GAMES BOWFINGER', Decimal('72.86'))
# ('EGYPT TENENBAUMS', Decimal('72.83'))
# ('POTTER CONNECTICUT', Decimal('72.83'))
# ('INSTINCT AIRPORT', Decimal('72.82'))
# ('NEIGHBORS CHARADE', Decimal('72.81'))
# ('LEBOWSKI SOLDIERS', Decimal('72.79'))
# ('SNOWMAN ROLLERCOASTER', Decimal('72.77'))
# ('HILLS NEIGHBORS', Decimal('72.75'))
# ('CARIBBEAN LIBERTY', Decimal('71.91'))
# ('ALABAMA DEVIL', Decimal('71.88'))
# ('BRINGING HYSTERICAL', Decimal('71.80'))
# ('CHARIOTS CONSPIRACY', Decimal('71.79'))
# ('SWARM GOLD', Decimal('71.73'))
# ('TEMPLE ATTRACTION', Decimal('70.88'))
# ('JINGLE SAGEBRUSH', Decimal('70.87'))
# ('SATURN NAME', Decimal('70.87'))
# ('USUAL UNTOUCHABLES', Decimal('70.87'))
# ('TURN STAR', Decimal('70.86'))
# ('DINOSAUR SECRETARY', Decimal('70.80'))
# ('AMISTAD MIDSUMMER', Decimal('70.79'))
# ('FAMILY SWEET', Decimal('70.70'))
# ('RUGRATS SHAKESPEARE', Decimal('70.70'))
# ('DAUGHTER MADIGAN', Decimal('69.91'))
# ('MOTHER OLEANDER', Decimal('69.86'))
# ('ARTIST COLDBLOODED', Decimal('69.84'))
# ('DRIVER ANNIE', Decimal('69.82'))
# ('POLLOCK DELIVERANCE', Decimal('69.81'))
# ('FLIGHT LIES', Decimal('68.88'))
# ('GUNFIGHTER MUSSOLINI', Decimal('68.88'))
# ('NOON PAPI', Decimal('68.83'))
# ('HONEY TIES', Decimal('68.81'))
# ('CHICKEN HELLFIGHTERS', Decimal('68.78'))
# ('DETECTIVE VISION', Decimal('68.73'))
# ('AMELIE HELLFIGHTERS', Decimal('67.90'))
# ('BILL OTHERS', Decimal('67.81'))
# ('DIVIDE MONSTER', Decimal('67.79'))
# ('EXCITEMENT EVE', Decimal('67.79'))
# ('ORANGE GRAPES', Decimal('67.76'))
# ('KING EVOLUTION', Decimal('66.91'))
# ('TWISTED PIRATES', Decimal('66.89'))
# ('DANGEROUS UPTOWN', Decimal('66.88'))
# ('OPPOSITE NECKLACE', Decimal('66.87'))
# ('BAREFOOT MANCHURIAN', Decimal('66.82'))
# ('WONKA SEA', Decimal('66.82'))
# ('NORTH TEQUILA', Decimal('65.89'))
# ('OPUS ICE', Decimal('65.89'))
# ('CHAMBER ITALIAN', Decimal('65.88'))
# ('MEET CHOCOLATE', Decimal('65.88'))
# ('WAR NOTTING', Decimal('65.88'))
# ('LOVELY JINGLE', Decimal('65.86'))
# ('CLONES PINOCCHIO', Decimal('65.81'))
# ('FIDDLER LOST', Decimal('64.90'))
# ('LOST BIRD', Decimal('64.88'))
# ('DIVINE RESURRECTION', Decimal('64.85'))
# ('MANCHURIAN CURTAIN', Decimal('64.85'))
# ('NASH CHOCOLAT', Decimal('64.85'))
# ('BEACH HEARTBREAKERS', Decimal('64.83'))
# ('POND SEATTLE', Decimal('64.81'))
# ('GILMORE BOILED', Decimal('64.72'))
# ('BIRD INDEPENDENCE', Decimal('63.89'))
# ('OCTOBER SUBMARINE', Decimal('63.89'))
# ('JAWS HARRY', Decimal('63.86'))
# ('MASK PEACH', Decimal('63.83'))
# ('BOULEVARD MOB', Decimal('63.82'))
# ('FURY MURDER', Decimal('63.81'))
# ('LOATHING LEGALLY', Decimal('63.73'))
# ('HANDICAP BOONDOCK', Decimal('63.72'))
# ('LOVER TRUMAN', Decimal('62.90'))
# ('GASLIGHT CRUSADE', Decimal('62.84'))
# ('REAP UNFAITHFUL', Decimal('62.84'))
# ('ALONE TRIP', Decimal('62.82'))
# ('JADE BUNCH', Decimal('62.82'))
# ('CIDER DESIRE', Decimal('62.81'))
# ('EARRING INSTINCT', Decimal('62.81'))
# ('WRONG BEHAVIOR', Decimal('62.80'))
# ('PACIFIC AMISTAD', Decimal('62.76'))
# ('DYNAMITE TARZAN', Decimal('62.75'))
# ('MOD SECRETARY', Decimal('61.89'))
# ('STATE WASTELAND', Decimal('61.88'))
# ('KICK SAVANNAH', Decimal('61.80'))
# ('PARK CITIZEN', Decimal('60.92'))
# ('SPARTACUS CHEAPER', Decimal('60.91'))
# ('CIRCUS YOUTH', Decimal('60.85'))
# ('UPRISING UPTOWN', Decimal('60.84'))
# ('ANACONDA CONFESSIONS', Decimal('60.79'))
# ('FIREBALL PHILADELPHIA', Decimal('60.79'))
# ('PACKER MADIGAN', Decimal('60.78'))
# ('TIGHTS DAWN', Decimal('60.74'))
# ('MADIGAN DORADO', Decimal('59.90'))
# ('BORN SPINAL', Decimal('59.88'))
# ('MASSAGE IMAGE', Decimal('59.88'))
# ('WINDOW SIDE', Decimal('59.88'))
# ('IDENTITY LOVER', Decimal('59.87'))
# ('NEMO CAMPUS', Decimal('59.86'))
# ('OUTFIELD MASSACRE', Decimal('59.80'))
# ('ANNIE IDENTITY', Decimal('59.78'))
# ('FIGHT JAWBREAKER', Decimal('59.78'))
# ('MOCKINGBIRD HOLLYWOOD', Decimal('59.76'))
# ('SMILE EARRING', Decimal('58.90'))
# ('TRAINSPOTTING STRANGERS', Decimal('58.89'))
# ('VALLEY PACKER', Decimal('58.85'))
# ('MUMMY CREATURES', Decimal('58.84'))
# ('WILLOW TRACY', Decimal('58.84'))
# ('HEAVEN FREEDOM', Decimal('58.82'))
# ('FICTION CHRISTMAS', Decimal('58.81'))
# ('DALMATIONS SWEDEN', Decimal('58.80'))
# ('KARATE MOON', Decimal('58.77'))
# ('GUYS FALCON', Decimal('57.91'))
# ('DOUBTFIRE LABYRINTH', Decimal('57.90'))
# ('LAMBS CINCINATTI', Decimal('57.90'))
# ('SIERRA DIVIDE', Decimal('57.85'))
# ('PILOT HOOSIERS', Decimal('57.84'))
# ('PERFECT GROOVE', Decimal('57.83'))
# ('ENOUGH RAGING', Decimal('57.82'))
# ('RACER EGG', Decimal('57.82'))
# ('GABLES METROPOLIS', Decimal('57.81'))
# ('RIVER OUTLAW', Decimal('57.81'))
# ('STRAIGHT HOURS', Decimal('57.80'))
# ('ELEMENT FREDDY', Decimal('56.90'))
# ('BOWFINGER GABLES', Decimal('56.89'))
# ('FUGITIVE MAGUIRE', Decimal('56.89'))
# ('CREATURES SHAKESPEARE', Decimal('56.84'))
# ('GRAPES FURY', Decimal('56.77'))
# ('WONDERFUL DROP', Decimal('55.91'))
# ('BUGSY SONG', Decimal('55.89'))
# ('IRON MOON', Decimal('55.89'))
# ('PURPLE MOVIE', Decimal('55.87'))
# ('ANALYZE HOOSIERS', Decimal('55.86'))
# ('SHANE DARKNESS', Decimal('55.86'))
# ('DIRTY ACE', Decimal('55.85'))
# ('PATRIOT ROMAN', Decimal('55.84'))
# ('GREEK EVERYONE', Decimal('55.83'))
# ('UNITED PILOT', Decimal('55.83'))
# ('GUNFIGHT MOON', Decimal('55.76'))
# ('SLUMS DUCK', Decimal('55.76'))
# ('DANCING FEVER', Decimal('55.73'))
# ('MAGNIFICENT CHITTY', Decimal('54.92'))
# ('ALI FOREVER', Decimal('54.91'))
# ('MONSOON CAUSE', Decimal('54.91'))
# ('GO PURPLE', Decimal('54.80'))
# ('FRISCO FORREST', Decimal('53.91'))
# ('NUTS TIES', Decimal('53.91'))
# ('HUNTING MUSKETEERS', Decimal('53.85'))
# ('SCISSORHANDS SLUMS', Decimal('53.85'))
# ('ROUGE SQUAD', Decimal('53.82'))
# ('REUNION WITCHES', Decimal('53.80'))
# ('SLEUTH ORIENT', Decimal('53.79'))
# ('EFFECT GLADIATOR', Decimal('53.75'))
# ('SUN CONFESSIONS', Decimal('53.75'))
# ('ACE GOLDFINGER', Decimal('52.93'))
# ('CASPER DRAGONFLY', Decimal('52.92'))
# ('REDS POCUS', Decimal('52.91'))
# ('VANILLA DAY', Decimal('52.91'))
# ('GRAIL FRANKENSTEIN', Decimal('52.90'))
# ('RIGHT CRANES', Decimal('52.90'))
# ('SENSIBILITY REAR', Decimal('52.90'))
# ('EXORCIST STING', Decimal('52.87'))
# ('ALLEY EVOLUTION', Decimal('52.86'))
# ('MADRE GABLES', Decimal('52.86'))
# ('SHRUNK DIVINE', Decimal('52.86'))
# ('GRADUATE LORD', Decimal('52.84'))
# ('FREAKY POCUS', Decimal('52.83'))
# ('NOVOCAINE FLIGHT', Decimal('52.81'))
# ('CHOCOLAT HARRY', Decimal('52.80'))
# ('HAUNTING PIANIST', Decimal('52.78'))
# ('ISHTAR ROCKETEER', Decimal('51.93'))
# ('PANIC CLUB', Decimal('51.93'))
# ('ELIZABETH SHANE', Decimal('51.90'))
# ('AFRICAN EGG', Decimal('51.88'))
# ('BREAKING HOME', Decimal('51.87'))
# ('MONSTER SPARTACUS', Decimal('51.85'))
# ('CADDYSHACK JEDI', Decimal('51.84'))
# ('MOULIN WAKE', Decimal('51.84'))
# ('PIRATES ROXANNE', Decimal('51.78'))
# ('VIRGINIAN PLUTO', Decimal('51.71'))
# ('CLERKS ANGELS', Decimal('50.93'))
# ('WORKER TARZAN', Decimal('50.85'))
# ('INDIAN LOVE', Decimal('50.84'))
# ('LOCK REAR', Decimal('50.84'))
# ('KWAI HOMEWARD', Decimal('50.77'))
# ('BOUND CHEAPER', Decimal('50.76'))
# ('DARLING BREAKING', Decimal('49.91'))
# ('INTOLERABLE INTENTIONS', Decimal('49.91'))
# ('SPEED SUIT', Decimal('49.91'))
# ('HOLLOW JEOPARDY', Decimal('49.90'))
# ('POTLUCK MIXED', Decimal('49.89'))
# ('EXPRESS LONELY', Decimal('49.87'))
# ('PERSONAL LADYBUGS', Decimal('49.86'))
# ('TOWN ARK', Decimal('49.86'))
# ('MODERN DORADO', Decimal('49.85'))
# ('WASTELAND DIVINE', Decimal('49.85'))
# ('HOURS RAGE', Decimal('49.81'))
# ('GOSFORD DONNIE', Decimal('48.92'))
# ('DROP WATERFRONT', Decimal('48.91'))
# ('LOLITA WORLD', Decimal('48.90'))
# ('RIDER CADDYSHACK', Decimal('48.89'))
# ('DARKNESS WAR', Decimal('48.87'))
# ('CYCLONE FAMILY', Decimal('48.86'))
# ('HAMLET WISDOM', Decimal('48.86'))
# ('VARSITY TRIP', Decimal('48.84'))
# ('ROCK INSTINCT', Decimal('48.83'))
# ('GOLDMINE TYCOON', Decimal('48.73'))
# ('VOYAGE LEGALLY', Decimal('48.72'))
# ('SENSE GREEK', Decimal('47.93'))
# ('CRUSADE HONEY', Decimal('47.92'))
# ('KRAMER CHOCOLATE', Decimal('47.91'))
# ('ENTRAPMENT SATISFACTION', Decimal('47.85'))
# ('LABYRINTH LEAGUE', Decimal('47.85'))
# ('SHIP WONDERLAND', Decimal('47.85'))
# ('NEWTON LABYRINTH', Decimal('47.83'))
# ('TRAMP OTHERS', Decimal('47.80'))
# ('GROSSE WONDERFUL', Decimal('46.92'))
# ('PUNK DIVORCE', Decimal('46.92'))
# ('ANYTHING SAVANNAH', Decimal('46.91'))
# ('HOTEL HAPPINESS', Decimal('46.91'))
# ('LEGALLY SECRETARY', Decimal('46.91'))
# ('STAGE WORLD', Decimal('46.90'))
# ('MICROCOSMOS PARADISE', Decimal('46.87'))
# ('PARIS WEEKEND', Decimal('46.86'))
# ('TROOPERS METAL', Decimal('46.86'))
# ('SHREK LICENSE', Decimal('46.85'))
# ('STORM HAPPINESS', Decimal('46.71'))
# ('BABY HALL', Decimal('45.92'))
# ('MATRIX SNOWMAN', Decimal('45.91'))
# ('PLATOON INSTINCT', Decimal('45.91'))
# ('ROLLERCOASTER BRINGING', Decimal('45.90'))
# ('SPEAKEASY DATE', Decimal('45.88'))
# ('DATE SPEED', Decimal('45.87'))
# ('STOCK GLASS', Decimal('45.86'))
# ('UNCUT SUICIDES', Decimal('45.86'))
# ('MIDNIGHT WESTWARD', Decimal('45.83'))
# ('ARMAGEDDON LOST', Decimal('45.79'))
# ('FANTASY TROOPERS', Decimal('45.74'))
# ('MIRACLE VIRTUAL', Decimal('44.91'))
# ('LIFE TWISTED', Decimal('44.90'))
# ('RUN PACIFIC', Decimal('44.90'))
# ('PARTY KNOCK', Decimal('44.87'))
# ('CLUB GRAFFITI', Decimal('44.80'))
# ('WOMEN DORADO', Decimal('44.78'))
# ('ALASKA PHANTOM', Decimal('44.74'))
# ('RECORDS ZORRO', Decimal('43.92'))
# ('FOREVER CANDIDATE', Decimal('43.87'))
# ('LUCKY FLYING', Decimal('43.87'))
# ('GLASS DYING', Decimal('43.86'))
# ('SHANGHAI TYCOON', Decimal('43.86'))
# ('NECKLACE OUTBREAK', Decimal('43.85'))
# ('MAJESTIC FLOATS', Decimal('43.83'))
# ('POCUS PULP', Decimal('43.74'))
# ('WARS PLUTO', Decimal('42.90'))
# ('CRANES RESERVOIR', Decimal('42.89'))
# ('LORD ARIZONA', Decimal('42.89'))
# ('PRIX UNDEFEATED', Decimal('42.89'))
# ('SADDLE ANTITRUST', Decimal('42.86'))
# ('ROOTS REMEMBER', Decimal('42.83'))
# ('COAST RAINBOW', Decimal('42.79'))
# ('MOURNING PURPLE', Decimal('42.79'))
# ('BANGER PINOCCHIO', Decimal('42.78'))
# ('EARLY HOME', Decimal('41.93'))
# ('HEAVENLY GUN', Decimal('41.93'))
# ('HOOSIERS BIRDCAGE', Decimal('41.92'))
# ('SOLDIERS EVOLUTION', Decimal('41.92'))
# ('FEATHERS METAL', Decimal('41.89'))
# ('MILE MULAN', Decimal('41.87'))
# ('SPIKING ELEMENT', Decimal('41.87'))
# ('ARMY FLINTSTONES', Decimal('41.84'))
# ('GROOVE FICTION', Decimal('41.82'))
# ('DISCIPLE MOTHER', Decimal('41.81'))
# ('SUNDANCE INVASION', Decimal('41.81'))
# ('CROOKED FROGMEN', Decimal('41.77'))
# ('CLUE GRAIL', Decimal('40.93'))
# ('EVE RESURRECTION', Decimal('40.93'))
# ('PRESIDENT BANG', Decimal('40.93'))
# ('TARZAN VIDEOTAPE', Decimal('40.92'))
# ('FRIDA SLIPPER', Decimal('40.90'))
# ('BLANKET BEVERLY', Decimal('40.88'))
# ('CABIN FLASH', Decimal('40.85'))
# ('SPLENDOR PATTON', Decimal('40.79'))
# ('JERSEY SASSY', Decimal('39.94'))
# ('TERMINATOR CLUB', Decimal('39.94'))
# ('ELF MURDER', Decimal('39.93'))
# ('FIRE WOLVES', Decimal('39.93'))
# ('STONE FIRE', Decimal('39.89'))
# ('ROBBERY BRIGHT', Decimal('39.87'))
# ('SPINAL ROCKY', Decimal('39.87'))
# ('PAJAMA JAWBREAKER', Decimal('39.86'))
# ('ILLUSION AMELIE', Decimal('39.85'))
# ('TOOTSIE PILOT', Decimal('39.85'))
# ('JOON NORTHWEST', Decimal('39.83'))
# ('ENCOUNTERS CURTAIN', Decimal('39.81'))
# ('CONGENIALITY QUEST', Decimal('39.78'))
# ('OUTBREAK DIVINE', Decimal('39.77'))
# ('FEUD FROGMEN', Decimal('39.75'))
# ('STORY SIDE', Decimal('39.72'))
# ('TALENTED HOMICIDE', Decimal('39.71'))
# ('ITALIAN AFRICAN', Decimal('38.94'))
# ('BLOOD ARGONAUTS', Decimal('38.90'))
# ('WAGON JAWS', Decimal('38.90'))
# ('DRUMLINE CYCLONE', Decimal('38.89'))
# ('MIGHTY LUCK', Decimal('38.88'))
# ('UPTOWN YOUNG', Decimal('38.88'))
# ('INDEPENDENCE HOTEL', Decimal('38.81'))
# ('PIANIST OUTFIELD', Decimal('38.78'))
# ('WIND PHANTOM', Decimal('38.77'))
# ('CAPER MOTIONS', Decimal('38.76'))
# ('CURTAIN VIDEOTAPE', Decimal('38.74'))
# ('MOON BUNCH', Decimal('38.71'))
# ('GRACELAND DYNAMITE', Decimal('37.94'))
# ('GODFATHER DIARY', Decimal('37.92'))
# ('VERTIGO NORTHWEST', Decimal('37.92'))
# ('SNATCHERS MONTEZUMA', Decimal('37.91'))
# ('ANTITRUST TOMATOES', Decimal('37.90'))
# ('ADAPTATION HOLES', Decimal('37.88'))
# ('HEDWIG ALTER', Decimal('37.88'))
# ('INTRIGUE WORST', Decimal('37.80'))
# ('SHOOTIST SUPERFLY', Decimal('37.76'))
# ('GUN BONNIE', Decimal('37.75'))
# ('WESTWARD SEABISCUIT', Decimal('37.74'))
# ('CONTROL ANTHEM', Decimal('36.93'))
# ('DOZEN LION', Decimal('36.93'))
# ('MULAN MOON', Decimal('36.87'))
# ('INSECTS STONE', Decimal('36.81'))
# ('CHEAPER CLYDE', Decimal('36.80'))
# ('VOLCANO TEXAS', Decimal('36.78'))
# ('ACADEMY DINOSAUR', Decimal('36.77'))
# ('PRIMARY GLASS', Decimal('36.73'))
# ('BUBBLE GROSSE', Decimal('35.94'))
# ('FRONTIER CABIN', Decimal('35.94'))
# ('SCHOOL JACKET', Decimal('35.94'))
# ('UNTOUCHABLES SUNRISE', Decimal('35.92'))
# ('GONE TROUBLE', Decimal('35.90'))
# ('HALLOWEEN NUTS', Decimal('35.90'))
# ('DONNIE ALLEY', Decimal('35.86'))
# ('LOVE SUICIDES', Decimal('35.80'))
# ('ALAMO VIDEOTAPE', Decimal('35.76'))
# ('DOCTOR GRAIL', Decimal('34.93'))
# ('RESERVOIR ADAPTATION', Decimal('34.90'))
# ('MAGNOLIA FORRESTER', Decimal('34.89'))
# ('SONG HEDWIG', Decimal('34.89'))
# ('MOB DUFFEL', Decimal('34.88'))
# ('RINGS HEARTBREAKERS', Decimal('34.85'))
# ('SUMMER SCARFACE', Decimal('34.84'))
# ('WATCH TRACY', Decimal('34.84'))
# ('TAXI KICK', Decimal('34.83'))
# ('LION UNCUT', Decimal('34.82'))
# ('BLADE POLISH', Decimal('34.79'))
# ('CARRIE BUNCH', Decimal('34.77'))
# ('EARTH VISION', Decimal('34.77'))
# ('FEVER EMPIRE', Decimal('33.95'))
# ('DIVORCE SHINING', Decimal('33.93'))
# ('MAGUIRE APACHE', Decimal('33.91'))
# ('SANTA PARIS', Decimal('33.89'))
# ('SPLASH GUMP', Decimal('33.86'))
# ('TRANSLATION SUMMER', Decimal('33.85'))
# ('ROXANNE REBEL', Decimal('33.81'))
# ('VOICE PEACH', Decimal('33.81'))
# ('AMADEUS HOLY', Decimal('33.79'))
# ('CHAINSAW UPTOWN', Decimal('33.79'))
# ('TEQUILA PAST', Decimal('32.94'))
# ('BULWORTH COMMANDMENTS', Decimal('32.93'))
# ('MAKER GABLES', Decimal('32.90'))
# ('NATURAL STOCK', Decimal('32.87'))
# ('STAMPEDE DISTURBING', Decimal('32.86'))
# ('MOTIONS DETAILS', Decimal('32.85'))
# ('BONNIE HOLOCAUST', Decimal('32.84'))
# ('FACTORY DRAGON', Decimal('32.83'))
# ('REAR TRADING', Decimal('32.83'))
# ('MARS ROMAN', Decimal('32.81'))
# ('HIGHBALL POTTER', Decimal('32.79'))
# ('ALTER VICTORY', Decimal('32.78'))
# ('CHILL LUCK', Decimal('32.78'))
# ('CELEBRITY HORN', Decimal('32.76'))
# ('SHEPHERD MIDSUMMER', Decimal('32.75'))
# ('DESPERATE TRAINSPOTTING', Decimal('31.94'))
# ('HAUNTED ANTITRUST', Decimal('31.94'))
# ('DESTINATION JERK', Decimal('31.92'))
# ('SAINTS BRIDE', Decimal('31.92'))
# ('DWARFS ALTER', Decimal('31.91'))
# ('RANDOM GO', Decimal('31.91'))
# ('DANCES NONE', Decimal('31.86'))
# ('SEVEN SWARM', Decimal('30.95'))
# ('APOCALYPSE FLAMINGOS', Decimal('30.94'))
# ('JUMANJI BLADE', Decimal('30.92'))
# ('DOLLS RAGE', Decimal('30.91'))
# ('LUCK OPUS', Decimal('30.90'))
# ('THEORY MERMAID', Decimal('30.88'))
# ('SLIPPER FIDELITY', Decimal('30.84'))
# ('EMPIRE MALKOVICH', Decimal('30.79'))
# ('DARES PLUTO', Decimal('29.91'))
# ('WISDOM WORKER', Decimal('29.91'))
# ('OLEANDER CLUE', Decimal('29.90'))
# ('SIDE ARK', Decimal('29.88'))
# ('CLEOPATRA DEVIL', Decimal('29.83'))
# ('LOUISIANA HARRY', Decimal('29.83'))
# ('ROOM ROMAN', Decimal('29.80'))
# ('ROMAN PUNK', Decimal('29.76'))
# ('COWBOY DOOM', Decimal('28.93'))
# ('LUKE MUMMY', Decimal('28.93'))
# ('PIZZA JUMANJI', Decimal('28.93'))
# ('CHITTY LOCK', Decimal('28.92'))
# ('PAPI NECKLACE', Decimal('28.92'))
# ('WON DARES', Decimal('28.91'))
# ('JEOPARDY ENCINO', Decimal('28.90'))
# ('FINDING ANACONDA', Decimal('28.88'))
# ('SAVANNAH TOWN', Decimal('28.88'))
# ('CHRISTMAS MOONSHINE', Decimal('28.79'))
# ('GREASE YOUTH', Decimal('28.79'))
# ('INFORMER DOUBLE', Decimal('27.95'))
# ('LEATHERNECKS DWARFS', Decimal('27.93'))
# ('SQUAD FISH', Decimal('27.93'))
# ('DIARY PANIC', Decimal('27.91'))
# ('DRAGON SQUAD', Decimal('27.89'))
# ('MINORITY KISS', Decimal('27.89'))
# ('CANYON STOCK', Decimal('27.81'))
# ('ENCINO ELF', Decimal('27.81'))
# ('BORROWERS BEDAZZLED', Decimal('27.78'))
# ('PRIVATE DROP', Decimal('26.95'))
# ('PET HAUNTING', Decimal('26.92'))
# ('UNFAITHFUL KILL', Decimal('26.92'))
# ('CRAZY HOME', Decimal('26.91'))
# ('EVOLUTION ALTER', Decimal('26.88'))
# ('RESURRECTION SILVERADO', Decimal('26.79'))
# ('BUNCH MINDS', Decimal('25.95'))
# ('DESIRE ALIEN', Decimal('25.92'))
# ('NOTORIOUS REUNION', Decimal('25.86'))
# ('MOSQUITO ARMAGEDDON', Decimal('25.85'))
# ('HOLOCAUST HIGHBALL', Decimal('25.83'))
# ('UNFORGIVEN ZOOLANDER', Decimal('25.82'))
# ('MASKED BUBBLE', Decimal('25.80'))
# ('DECEIVER BETRAYED', Decimal('25.79'))
# ('TRAIN BUNCH', Decimal('24.96'))
# ('HUNTER ALTER', Decimal('24.95'))
# ('TRAFFIC HOBBIT', Decimal('24.95'))
# ('BED HIGHBALL', Decimal('24.94'))
# ('WORLD LEATHERNECKS', Decimal('24.92'))
# ('GATHERING CALENDAR', Decimal('24.89'))
# ('DRUMS DYNAMITE', Decimal('24.87'))
# ('EVERYONE CRAFT', Decimal('24.87'))
# ('STREAK RIDGEMONT', Decimal('24.84'))
# ('POLISH BROOKLYN', Decimal('24.82'))
# ('PATIENT SISTER', Decimal('24.81'))
# ('DRACULA CRYSTAL', Decimal('24.79'))
# ('WOLVES DESIRE', Decimal('24.79'))
# ('MANNEQUIN WORST', Decimal('23.95'))
# ('CASSIDY WYOMING', Decimal('23.94'))
# ('DUCK RACER', Decimal('23.94'))
# ('LESSON CLEOPATRA', Decimal('23.93'))
# ('CHAPLIN LICENSE', Decimal('23.92'))
# ('CLYDE THEORY', Decimal('23.92'))
# ('BIRDCAGE CASPER', Decimal('23.91'))
# ('REEF SALUTE', Decimal('23.89'))
# ('WRATH MILE', Decimal('23.86'))
# ('ODDS BOOGIE', Decimal('23.85'))
# ('HOMEWARD CIDER', Decimal('23.84'))
# ('EXTRAORDINARY CONQUERER', Decimal('22.94'))
# ('HAPPINESS UNITED', Decimal('22.94'))
# ('BANG KWAI', Decimal('22.93'))
# ('LICENSE WEEKEND', Decimal('22.93'))
# ('NEWSIES STORY', Decimal('22.93'))
# ('SHINING ROSES', Decimal('22.92'))
# ('ARABIA DOGMA', Decimal('22.87'))
# ('HUNGER ROOF', Decimal('22.87'))
# ('VIETNAM SMOOCHY', Decimal('22.85'))
# ('GANDHI KWAI', Decimal('22.83'))
# ('MUSIC BOONDOCK', Decimal('22.81'))
# ('KILLER INNOCENT', Decimal('21.94'))
# ('PHANTOM GLORY', Decimal('21.94'))
# ('WARLOCK WEREWOLF', Decimal('21.94'))
# ('MENAGERIE RUSHMORE', Decimal('21.93'))
# ('MULHOLLAND BEAST', Decimal('21.93'))
# ('CITIZEN SHREK', Decimal('21.87'))
# ('MONTEREY LABYRINTH', Decimal('21.87'))
# ('BULL SHAWSHANK', Decimal('21.84'))
# ('BRIDE INTRIGUE', Decimal('21.81'))
# ('JEDI BENEATH', Decimal('21.81'))
# ('IMPACT ALADDIN', Decimal('20.91'))
# ('SPOILERS HELLFIGHTERS', Decimal('20.90'))
# ('TENENBAUMS COMMAND', Decimal('20.87'))
# ('KANE EXORCIST', Decimal('20.86'))
# ('CRAFT OUTFIELD', Decimal('20.84'))
# ('MYSTIC TRUMAN', Decimal('19.90'))
# ('LANGUAGE COWBOY', Decimal('19.89'))
# ('SPIRITED CASUALTIES', Decimal('19.89'))
# ('LOVERBOY ATTACKS', Decimal('19.88'))
# ('SORORITY QUEEN', Decimal('19.88'))
# ('TOMATOES HELLFIGHTERS', Decimal('19.86'))
# ('RUSHMORE MERMAID', Decimal('18.94'))
# ('SIMON NORTH', Decimal('18.94'))
# ('HOLY TADPOLE', Decimal('18.91'))
# ('ENDING CROWDS', Decimal('18.89'))
# ('CROW GREASE', Decimal('18.88'))
# ('PRIDE ALAMO', Decimal('18.84'))
# ('SMOKING BARBARELLA', Decimal('18.83'))
# ('LADYBUGS ARMAGEDDON', Decimal('17.94'))
# ('MAGIC MALLRATS', Decimal('17.93'))
# ('GILBERT PELICAN', Decimal('17.91'))
# ('SUPERFLY TRIP', Decimal('17.90'))
# ('ANONYMOUS HUMAN', Decimal('17.87'))
# ('HOOK CHARIOTS', Decimal('17.87'))
# ('SIEGE MADRE', Decimal('17.85'))
# ('BRAVEHEART HUMAN', Decimal('16.95'))
# ('CONSPIRACY SPIRIT', Decimal('16.95'))
# ('FULL FLATLINERS', Decimal('16.95'))
# ('YOUTH KICK', Decimal('16.94'))
# ('BENEATH RUSH', Decimal('16.90'))
# ('FROGMEN BREAKING', Decimal('16.90'))
# ('BEETHOVEN EXORCIST', Decimal('16.89'))
# ('VALENTINE VANISHING', Decimal('16.88'))
# ('BEDAZZLED MARRIED', Decimal('16.87'))
# ('SILENCE KANE', Decimal('16.84'))
# ('HARDLY ROBBERS', Decimal('15.96'))
# ('MIXED DOORS', Decimal('15.96'))
# ('MUSSOLINI SPOILERS', Decimal('15.95'))
# ('WILD APOLLO', Decimal('15.94'))
# ('HAWK CHILL', Decimal('15.93'))
# ('VISION TORQUE', Decimal('15.93'))
# ('JUNGLE CLOSER', Decimal('15.91'))
# ('LAWRENCE LOVE', Decimal('15.87'))
# ('SASSY PACKER', Decimal('15.87'))
# ('GREEDY ROOTS', Decimal('15.86'))
# ('SPIRIT FLINTSTONES', Decimal('15.85'))
# ('GLORY TRACY', Decimal('14.95'))
# ('SLING LUKE', Decimal('14.94'))
# ('VANISHED GARDEN', Decimal('14.94'))
# ('RUNNER MADIGAN', Decimal('14.92'))
# ('ZHIVAGO CORE', Decimal('14.91'))
# ('SMOOCHY CONTROL', Decimal('14.88'))
# ('DUMBO LUST', Decimal('13.94'))
# ('WATERSHIP FRONTIER', Decimal('13.94'))
# ('LEGEND JEDI', Decimal('13.91'))
# ('NOTTING SPEAKEASY', Decimal('13.90'))
# ('HOLLYWOOD ANONYMOUS', Decimal('13.87'))
# ('TREATMENT JEKYLL', Decimal('12.93'))
# ('RUNAWAY TENENBAUMS', Decimal('12.92'))
# ('SOUP WISDOM', Decimal('12.92'))
# ('SUNSET RACER', Decimal('12.92'))
# ('VICTORY ACADEMY', Decimal('12.91'))
# ('TOWERS HURRICANE', Decimal('12.89'))
# ('MAUDE MOD', Decimal('11.92'))
# ('GHOSTBUSTERS ELF', Decimal('11.91'))
# ('MONTEZUMA COMMAND', Decimal('11.91'))
# ('CLOCKWORK PARADISE', Decimal('11.90'))
# ('JAWBREAKER BROOKLYN', Decimal('11.90'))
# ('CONNECTION MICROCOSMOS', Decimal('10.93'))
# ('BALLROOM MOCKINGBIRD', Decimal('10.92'))
# ('COMANCHEROS ENEMY', Decimal('9.94'))
# ('HAROLD FRENCH', Decimal('9.92'))
# ('LIGHTS DEER', Decimal('9.92'))
# ('STALLION SUNDANCE', Decimal('8.93'))
# ('JAPANESE RUN', Decimal('7.94'))
# ('CRUELTY UNFORGIVEN', Decimal('7.93'))
# ('REBEL AIRPORT', Decimal('7.92'))
# ('DUFFEL APOCALYPSE', Decimal('6.93'))
# ('YOUNG LANGUAGE', Decimal('6.93'))
# ('FREEDOM CLEOPATRA', Decimal('5.95'))
# ('OKLAHOMA JUMANJI', Decimal('5.94'))
# ('TEXAS WATCH', Decimal('5.94'))

# %% [markdown]
# ### Run query to find revenues made from cities

# %%
db_cursor.execute("""SELECT c1.country, c2.city , sum(p.amount) as revenue from payment as p
JOIN customer c3 ON p.customer_id = c3.customer_id
JOIN address a ON c3.address_id= a.address_id
JOIN city c2 ON a.city_id= c2.city_id
JOIN country c1 ON c2.country_id= c1.country_id
GROUP BY c2.city, c1.country
ORDER BY revenue desc""")
iterate_cursor(db_cursor)
# Out:
# ('country', 'city', 'revenue')
# ('United States', 'Cape Coral', Decimal('221.55'))
# ('Réunion', 'Saint-Denis', Decimal('216.54'))
# ('United States', 'Aurora', Decimal('198.50'))
# ('Belarus', 'Molodetšno', Decimal('195.58'))
# ('Netherlands', 'Apeldoorn', Decimal('194.61'))
# ('Brazil', 'Santa Brbara dOeste', Decimal('194.61'))
# ('Iran', 'Qomsheh', Decimal('186.62'))
# ('United Kingdom', 'London', Decimal('180.52'))
# ('Spain', 'Ourense (Orense)', Decimal('177.60'))
# ('India', 'Bijapur', Decimal('175.61'))
# ('Philippines', 'Tanza', Decimal('175.58'))
# ('United States', 'Memphis', Decimal('174.66'))
# ('Algeria', 'Skikda', Decimal('173.63'))
# ('Sudan', 'Omdurman', Decimal('169.65'))
# ('India', 'Halisahar', Decimal('168.68'))
# ('Philippines', 'Santa Rosa', Decimal('167.67'))
# ('Canada', 'Richmond Hill', Decimal('167.62'))
# ('India', 'Valparai', Decimal('166.65'))
# ('Russian Federation', 'Kolpino', Decimal('162.62'))
# ('India', 'Bhilwara', Decimal('161.68'))
# ('Philippines', 'Tanauan', Decimal('161.65'))
# ('Yemen', 'Hodeida', Decimal('160.68'))
# ('Ukraine', 'Sumy', Decimal('159.72'))
# ('China', 'Zhoushan', Decimal('159.68'))
# ('Russian Federation', 'Usolje-Sibirskoje', Decimal('159.67'))
# ('China', 'Lengshuijiang', Decimal('159.64'))
# ('Spain', 'Donostia-San Sebastián', Decimal('158.69'))
# ('Indonesia', 'Probolinggo', Decimal('158.66'))
# ('Mexico', 'Salamanca', Decimal('157.65'))
# ('Iran', 'Najafabad', Decimal('157.65'))
# ('Russian Federation', 'Maikop', Decimal('155.68'))
# ('Bangladesh', 'Tangail', Decimal('155.65'))
# ('Taiwan', 'Changhwa', Decimal('155.59'))
# ('China', 'Changzhou', Decimal('154.60'))
# ('Egypt', 'Shubra al-Khayma', Decimal('153.66'))
# ('Vietnam', 'Cam Ranh', Decimal('152.68'))
# ('Thailand', 'Nakhon Sawan', Decimal('152.67'))
# ('Holy See (Vatican City State)', 'Città del Vaticano', Decimal('152.66'))
# ('India', 'Karnal', Decimal('152.65'))
# ('Indonesia', 'Pontianak', Decimal('152.65'))
# ('Turkey', 'Balikesir', Decimal('152.63'))
# ('Yugoslavia', 'Kragujevac', Decimal('151.67'))
# ('Mexico', 'Uruapan', Decimal('151.67'))
# ('China', 'Fuyu', Decimal('151.66'))
# ('Germany', 'Mannheim', Decimal('151.65'))
# ('Italy', 'Bergamo', Decimal('151.64'))
# ('Mozambique', 'Beira', Decimal('151.63'))
# ('Puerto Rico', 'Arecibo', Decimal('150.66'))
# ('Philippines', 'Cabuyao', Decimal('149.65'))
# ('Nauru', 'Yangor', Decimal('148.69'))
# ('Thailand', 'Songkhla', Decimal('148.67'))
# ('Italy', 'Brescia', Decimal('147.69'))
# ('Turkey', 'Usak', Decimal('147.65'))
# ('Nigeria', 'Ilorin', Decimal('146.69'))
# ('United States', 'Akron', Decimal('146.69'))
# ('Taiwan', 'Hsichuh', Decimal('146.64'))
# ('Colombia', 'Sincelejo', Decimal('145.70'))
# ('Brazil', 'Belém', Decimal('145.68'))
# ('Turkey', 'Batman', Decimal('145.67'))
# ('Canada', 'Vancouver', Decimal('144.70'))
# ('Nigeria', 'Ogbomosho', Decimal('144.68'))
# ('South Korea', 'Naju', Decimal('144.67'))
# ('Sweden', 'Malmö', Decimal('144.66'))
# ('Taiwan', 'Nantou', Decimal('144.62'))
# ('Japan', 'Onomichi', Decimal('143.71'))
# ('Kenya', 'Nyeri', Decimal('143.71'))
# ('Colombia', 'Dos Quebradas', Decimal('143.68'))
# ('Hong Kong', 'Kowloon and New Kowloon', Decimal('142.70'))
# ('Latvia', 'Daugavpils', Decimal('142.70'))
# ('Russian Federation', 'Moscow', Decimal('142.66'))
# ('Indonesia', 'Ciomas', Decimal('142.66'))
# ('Brazil', 'Vila Velha', Decimal('141.71'))
# ('Vietnam', 'Nam Dinh', Decimal('141.70'))
# ('India', 'Rae Bareli', Decimal('141.69'))
# ('Mexico', 'Atlixco', Decimal('141.67'))
# ('China', 'Binzhou', Decimal('141.67'))
# ('Turkey', 'Tokat', Decimal('141.66'))
# ('Nigeria', 'Ikerre', Decimal('141.63'))
# ('Ecuador', 'Ríobamba', Decimal('140.69'))
# ('China', 'Qinhuangdao', Decimal('140.68'))
# ('Japan', 'Shimonoseki', Decimal('140.64'))
# ('United States', 'Sterling Heights', Decimal('139.71'))
# ('Mexico', 'Cuauhtémoc', Decimal('139.71'))
# ('Japan', 'Omiya', Decimal('139.70'))
# ('China', 'Yinchuan', Decimal('139.70'))
# ('Germany', 'Duisburg', Decimal('139.67'))
# ('Taiwan', 'Fengshan', Decimal('139.66'))
# ('Philippines', 'Imus', Decimal('138.71'))
# ('Mexico', 'Coatzacoalcos', Decimal('138.71'))
# ('Malaysia', 'Sungai Petani', Decimal('138.68'))
# ('United States', 'Fontana', Decimal('138.67'))
# ('India', 'Siliguri (Shiliguri)', Decimal('138.66'))
# ('Nigeria', 'Ife', Decimal('137.70'))
# ('Yemen', 'Aden', Decimal('137.69'))
# ('India', 'Parbhani', Decimal('137.69'))
# ('Israel', 'Ashdod', Decimal('137.67'))
# ('Greenland', 'Nuuk', Decimal('137.66'))
# ('Turkmenistan', 'Ashgabat', Decimal('136.73'))
# ('Poland', 'Tychy', Decimal('136.64'))
# ('Greece', 'Athenai', Decimal('135.74'))
# ('Japan', 'Otsu', Decimal('135.74'))
# ('Poland', 'Wroclaw', Decimal('135.72'))
# ('Germany', 'Erlangen', Decimal('135.71'))
# ('French Polynesia', 'Papeete', Decimal('135.70'))
# ('Azerbaijan', 'Sumqayit', Decimal('135.70'))
# ('Iran', 'Tabriz', Decimal('135.69'))
# ('South Africa', 'Boksburg', Decimal('135.68'))
# ('Chad', 'NDjamna', Decimal('135.68'))
# ('China', 'Jinchang', Decimal('135.66'))
# ('Brazil', 'Juiz de Fora', Decimal('134.73'))
# ('Brazil', 'Angra dos Reis', Decimal('134.70'))
# ('India', 'Bhopal', Decimal('134.68'))
# ('Argentina', 'La Plata', Decimal('134.68'))
# ('Vietnam', 'Nha Trang', Decimal('134.68'))
# ('China', 'Leshan', Decimal('134.68'))
# ('Zambia', 'Kitwe', Decimal('134.67'))
# ('Indonesia', 'Lhokseumawe', Decimal('134.66'))
# ('Mozambique', 'Naçala-Porto', Decimal('133.75'))
# ('India', 'Mysore', Decimal('133.73'))
# ('Brazil', 'Goiânia', Decimal('133.72'))
# ('United States', 'Joliet', Decimal('133.72'))
# ('Russian Federation', 'Kirovo-Tšepetsk', Decimal('133.71'))
# ('Czech Republic', 'Olomouc', Decimal('133.71'))
# ('United States', 'Lancaster', Decimal('133.70'))
# ('Italy', 'Syrakusa', Decimal('132.72'))
# ('India', 'Miraj', Decimal('132.71'))
# ('Mexico', 'Huixquilucan', Decimal('132.70'))
# ('Mexico', 'San Felipe del Progreso', Decimal('132.70'))
# ('Argentina', 'Avellaneda', Decimal('132.70'))
# ('South Korea', 'Uijongbu', Decimal('132.68'))
# ('Turkey', 'Osmaniye', Decimal('131.73'))
# ('Japan', 'Hiroshima', Decimal('131.70'))
# ('Brazil', 'Sorocaba', Decimal('131.67'))
# ('Ukraine', 'Simferopol', Decimal('130.74'))
# ('China', 'Jining', Decimal('130.73'))
# ('Saudi Arabia', 'Jedda', Decimal('130.72'))
# ('China', 'Yuncheng', Decimal('130.70'))
# ('Japan', 'Fukuyama', Decimal('130.68'))
# ('Brazil', 'Boa Vista', Decimal('130.68'))
# ('United Kingdom', 'York', Decimal('129.72'))
# ('Ecuador', 'Loja', Decimal('129.72'))
# ('Philippines', 'Baybay', Decimal('129.70'))
# ('United States', 'Salinas', Decimal('129.70'))
# ('India', 'Patiala', Decimal('129.70'))
# ('Gambia', 'Banjul', Decimal('129.70'))
# ('France', 'Toulouse', Decimal('129.68'))
# ('Philippines', 'Lapu-Lapu', Decimal('129.68'))
# ('Brazil', 'Santo André', Decimal('129.64'))
# ('United States', 'San Bernardino', Decimal('128.73'))
# ('Philippines', 'Ozamis', Decimal('128.73'))
# ('Argentina', 'Bahía Blanca', Decimal('128.72'))
# ('Japan', 'Iwakuni', Decimal('128.71'))
# ('Ukraine', 'Mukatševe', Decimal('128.70'))
# ('India', 'Ahmadnagar', Decimal('128.67'))
# ('Mexico', 'El Fuerte', Decimal('128.67'))
# ('India', 'Vijayawada', Decimal('127.75'))
# ('Chile', 'Antofagasta', Decimal('127.73'))
# ('India', 'Jhansi', Decimal('127.71'))
# ('Japan', 'Miyakonojo', Decimal('127.71'))
# ('China', 'Tiefa', Decimal('127.71'))
# ('China', 'Xinxiang', Decimal('127.70'))
# ('Poland', 'Jastrzebie-Zdrój', Decimal('127.68'))
# ('Bangladesh', 'Jamalpur', Decimal('127.68'))
# ('Moldova', 'Chisinau', Decimal('127.66'))
# ('Japan', 'Urawa', Decimal('127.66'))
# ('Brazil', 'Blumenau', Decimal('126.73'))
# ('India', 'Purnea (Purnia)', Decimal('126.73'))
# ('Nigeria', 'Benin City', Decimal('126.72'))
# ('Chile', 'Coquimbo', Decimal('126.72'))
# ('Peru', 'Huánuco', Decimal('126.71'))
# ('Mexico', 'Cuernavaca', Decimal('126.71'))
# ('Argentina', 'Merlo', Decimal('126.70'))
# ('Philippines', 'Davao', Decimal('126.69'))
# ('Peru', 'Lima', Decimal('126.68'))
# ('United States', 'Greensboro', Decimal('126.68'))
# ('South Africa', 'Kimberley', Decimal('125.76'))
# ('China', 'Emeishan', Decimal('124.74'))
# ('Egypt', 'Mit Ghamr', Decimal('124.73'))
# ('United States', 'Dallas', Decimal('124.72'))
# ('Philippines', 'Cavite', Decimal('124.70'))
# ('Romania', 'Botosani', Decimal('124.67'))
# ('China', 'Liaocheng', Decimal('124.66'))
# ('Malawi', 'Lilongwe', Decimal('123.72'))
# ('India', 'Palghat (Palakkad)', Decimal('123.71'))
# ('Italy', 'Brindisi', Decimal('123.70'))
# ('Taiwan', 'Lungtan', Decimal('123.66'))
# ('Russian Federation', 'Kamyšin', Decimal('122.74'))
# ('Argentina', 'Santa Fé', Decimal('122.73'))
# ('United States', 'Warren', Decimal('122.72'))
# ('Japan', 'Kakamigahara', Decimal('122.71'))
# ('Philippines', 'Mandaluyong', Decimal('122.71'))
# ('China', 'Datong', Decimal('122.69'))
# ('Virgin Islands, U.S.', 'Charlotte Amalie', Decimal('122.68'))
# ('China', 'Xi´angfan', Decimal('122.66'))
# ('Poland', 'Plock', Decimal('121.76'))
# ('United States', 'Brockton', Decimal('121.74'))
# ('India', 'Satna', Decimal('121.70'))
# ('Russian Federation', 'Korolev', Decimal('121.69'))
# ('Pakistan', 'Dadu', Decimal('121.69'))
# ('Russian Federation', 'Kursk', Decimal('120.77'))
# ('Tuvalu', 'Funafuti', Decimal('120.74'))
# ('India', 'Ambattur', Decimal('120.74'))
# ('Egypt', 'Sawhaj', Decimal('120.74'))
# ('China', 'Baiyin', Decimal('120.74'))
# ('Kazakstan', 'Zhezqazghan', Decimal('120.71'))
# ('Germany', 'Halle/Saale', Decimal('120.69'))
# ('India', 'Udaipur', Decimal('119.74'))
# ('Russian Federation', 'Pjatigorsk', Decimal('119.74'))
# ('India', 'Pudukkottai', Decimal('119.73'))
# ('Ecuador', 'Portoviejo', Decimal('119.72'))
# ('Austria', 'Graz', Decimal('119.71'))
# ('Latvia', 'Liepaja', Decimal('119.70'))
# ('India', 'Rampur', Decimal('119.70'))
# ('Vietnam', 'Hanoi', Decimal('119.69'))
# ('India', 'Chandrapur', Decimal('119.68'))
# ('Armenia', 'Yerevan', Decimal('118.75'))
# ('Japan', 'Kuwana', Decimal('118.75'))
# ('Nigeria', 'Owo', Decimal('118.73'))
# ('United Arab Emirates', 'Sharja', Decimal('118.73'))
# ('United Kingdom', 'Southend-on-Sea', Decimal('118.72'))
# ('Austria', 'Salzburg', Decimal('118.72'))
# ('Bangladesh', 'Dhaka', Decimal('118.72'))
# ('India', 'Bhimavaram', Decimal('118.71'))
# ('Japan', 'Sasebo', Decimal('118.68'))
# ('China', 'Tongliao', Decimal('118.68'))
# ('United Kingdom', 'Southampton', Decimal('117.77'))
# ('Colombia', 'Sogamoso', Decimal('117.76'))
# ('Argentina', 'Quilmes', Decimal('117.76'))
# ('South Korea', 'Tonghae', Decimal('117.75'))
# ('Japan', 'Iwaki', Decimal('117.74'))
# ('Nigeria', 'Effon-Alaiye', Decimal('117.73'))
# ('Taiwan', 'Tanshui', Decimal('117.73'))
# ('United States', 'Citrus Heights', Decimal('117.72'))
# ('Brazil', 'Poá', Decimal('117.72'))
# ('Ukraine', 'Kamjanets-Podilskyi', Decimal('117.71'))
# ('China', 'Baicheng', Decimal('117.71'))
# ('Thailand', 'Pak Kret', Decimal('117.70'))
# ('China', 'Jinzhou', Decimal('117.70'))
# ('Nepal', 'Birgunj', Decimal('116.78'))
# ('South Africa', 'Newcastle', Decimal('116.77'))
# ('Sri Lanka', 'Jaffna', Decimal('116.70'))
# ('United States', 'Sunnyvale', Decimal('116.69'))
# ('India', 'Uluberia', Decimal('116.69'))
# ('Brazil', 'Poços de Caldas', Decimal('116.68'))
# ('Peru', 'Callao', Decimal('115.74'))
# ('Malaysia', 'Kuching', Decimal('115.73'))
# ('Indonesia', 'Madiun', Decimal('115.72'))
# ('Pakistan', 'Shikarpur', Decimal('115.71'))
# ('India', 'Tambaram', Decimal('115.71'))
# ('Tanzania', 'Mwanza', Decimal('115.71'))
# ('China', 'Shaoguan', Decimal('115.71'))
# ('China', 'Weifang', Decimal('115.71'))
# ('Pakistan', 'Mardan', Decimal('115.70'))
# ('Japan', 'Nagareyama', Decimal('115.70'))
# ('Estonia', 'Tartu', Decimal('115.70'))
# ('Japan', 'Ueda', Decimal('115.68'))
# ('Brazil', 'Guarujá', Decimal('114.76'))
# ('Mexico', 'Mexicali', Decimal('114.75'))
# ('Russian Federation', 'Lipetsk', Decimal('114.74'))
# ('Malaysia', 'Ipoh', Decimal('114.74'))
# ('Tanzania', 'Zanzibar', Decimal('114.73'))
# ('Liechtenstein', 'Vaduz', Decimal('114.72'))
# ('Faroe Islands', 'Tórshavn', Decimal('114.72'))
# ('South Africa', 'Paarl', Decimal('114.72'))
# ('United States', 'Rockford', Decimal('114.72'))
# ('India', 'Haldia', Decimal('114.69'))
# ('Mexico', 'Cuautla', Decimal('114.69'))
# ('Morocco', 'Salé', Decimal('113.78'))
# ('Mexico', 'Huejutla de Reyes', Decimal('113.75'))
# ('United States', 'Dayton', Decimal('113.74'))
# ('Mexico', 'Acuña', Decimal('113.74'))
# ('United States', 'Garden Grove', Decimal('113.74'))
# ('Taiwan', 'Touliu', Decimal('113.73'))
# ('Venezuela', 'Cumaná', Decimal('113.71'))
# ('Russian Federation', 'Nabereznyje Tšelny', Decimal('113.71'))
# ('North Korea', 'Pyongyang', Decimal('113.69'))
# ('Brunei', 'Bandar Seri Begawan', Decimal('113.65'))
# ('Turkey', 'Sultanbeyli', Decimal('112.77'))
# ('Bulgaria', 'Ruse', Decimal('112.76'))
# ('United States', 'Lincoln', Decimal('112.75'))
# ('Bahrain', 'al-Manama', Decimal('112.75'))
# ('Turkey', 'Adana', Decimal('112.74'))
# ('South Africa', 'Rustenburg', Decimal('112.73'))
# ('Algeria', 'Batna', Decimal('112.72'))
# ('Israel', 'Tel Aviv-Jaffa', Decimal('112.70'))
# ('Myanmar', 'Monywa', Decimal('112.70'))
# ('Venezuela', 'Maracaíbo', Decimal('111.77'))
# ('Angola', 'Benguela', Decimal('111.75'))
# ('Kuwait', 'Jalib al-Shuyukh', Decimal('111.74'))
# ('Turkey', 'Sivas', Decimal('111.74'))
# ('Indonesia', 'Pemalang', Decimal('111.73'))
# ('Japan', 'Iwatsuki', Decimal('111.73'))
# ('Iraq', 'Mosul', Decimal('111.73'))
# ('Yemen', 'Taizz', Decimal('111.72'))
# ('Hungary', 'Székesfehérvár', Decimal('111.71'))
# ('India', 'Munger (Monghyr)', Decimal('111.68'))
# ('Dominican Republic', 'Santiago de los Caballeros', Decimal('110.76'))
# ('Congo, The Democratic Republic of the', 'Mwene-Ditu', Decimal('110.76'))
# ('Saudi Arabia', 'al-Qatif', Decimal('110.75'))
# ('India', 'Uttarpara-Kotrung', Decimal('110.74'))
# ('Morocco', 'Nador', Decimal('110.73'))
# ('Tanzania', 'Tabora', Decimal('110.73'))
# ('China', 'Meixian', Decimal('110.72'))
# ('Russian Federation', 'Kurgan', Decimal('110.72'))
# ('Egypt', 'Bilbays', Decimal('110.72'))
# ('Romania', 'Bucuresti', Decimal('110.71'))
# ('India', 'Pune', Decimal('110.70'))
# ('China', 'Shanwei', Decimal('110.70'))
# ('China', 'Hohhot', Decimal('110.66'))
# ('United Kingdom', 'Stockport', Decimal('109.78'))
# ('Switzerland', 'Bern', Decimal('109.75'))
# ('Kenya', 'Kisumu', Decimal('109.75'))
# ('United States', 'Arlington', Decimal('109.75'))
# ('Colombia', 'Florencia', Decimal('109.75'))
# ('Nigeria', 'Sokoto', Decimal('109.75'))
# ('India', 'Etawah', Decimal('109.74'))
# ('Azerbaijan', 'Baku', Decimal('109.73'))
# ('South Africa', 'Johannesburg', Decimal('109.73'))
# ('Venezuela', 'Valle de la Pascua', Decimal('109.72'))
# ('Japan', 'Akishima', Decimal('109.72'))
# ('Argentina', 'Tandil', Decimal('109.68'))
# ('Brazil', 'Juazeiro do Norte', Decimal('108.78'))
# ('Italy', 'Livorno', Decimal('108.76'))
# ('Germany', 'Witten', Decimal('108.75'))
# ('Poland', 'Czestochowa', Decimal('108.75'))
# ('Mexico', 'Celaya', Decimal('108.74'))
# ('South Africa', 'Soshanguve', Decimal('108.72'))
# ('United States', 'Peoria', Decimal('108.70'))
# ('Brazil', 'Maringá', Decimal('107.77'))
# ('China', 'Tianjin', Decimal('107.77'))
# ('Russian Federation', 'Smolensk', Decimal('107.76'))
# ('Yugoslavia', 'Novi Sad', Decimal('107.76'))
# ('South Africa', 'Klerksdorp', Decimal('107.74'))
# ('Philippines', 'Tuguegarao', Decimal('107.74'))
# ('Mexico', 'José Azueta', Decimal('107.73'))
# ('Spain', 'A Coruña (La Coruña)', Decimal('107.71'))
# ('Dominican Republic', 'San Felipe de Puerto Plata', Decimal('107.70'))
# ('United Arab Emirates', 'Abu Dhabi', Decimal('107.68'))
# ('Netherlands', 'Ede', Decimal('106.77'))
# ('Paraguay', 'San Lorenzo', Decimal('106.77'))
# ('India', 'Bhavnagar', Decimal('106.77'))
# ('Japan', 'Sagamihara', Decimal('106.76'))
# ('United Arab Emirates', 'al-Ayn', Decimal('106.75'))
# ('Russian Federation', 'Ljubertsy', Decimal('106.73'))
# ('Anguilla', 'South Hill', Decimal('106.65'))
# ('Japan', 'Tsuyama', Decimal('105.79'))
# ('Mexico', 'Hidalgo', Decimal('105.75'))
# ('United States', 'Kansas City', Decimal('105.75'))
# ('Mexico', 'Allende', Decimal('105.75'))
# ('Taiwan', 'Chungho', Decimal('105.75'))
# ('United States', 'Augusta-Richmond County', Decimal('105.73'))
# ('Russian Federation', 'Atšinsk', Decimal('105.71'))
# ('Mexico', 'Coacalco de Berriozábal', Decimal('104.78'))
# ('Nigeria', 'Deba Habe', Decimal('104.77'))
# ('China', 'Dongying', Decimal('104.77'))
# ('Poland', 'Kalisz', Decimal('104.75'))
# ('India', 'Kamarhati', Decimal('104.74'))
# ('Saudi Arabia', 'Tabuk', Decimal('104.74'))
# ('Mexico', 'San Juan Bautista Tuxtepec', Decimal('104.74'))
# ('Japan', 'Izumisano', Decimal('104.70'))
# ('French Guiana', 'Cayenne', Decimal('103.78'))
# ('Japan', 'Okinawa', Decimal('103.77'))
# ('Japan', 'Isesaki', Decimal('103.77'))
# ('Ukraine', 'Šostka', Decimal('103.76'))
# ('Vietnam', 'Haiphong', Decimal('103.75'))
# ('China', 'Yuzhou', Decimal('103.75'))
# ('China', 'Sanya', Decimal('103.75'))
# ('India', 'Bhusawal', Decimal('103.74'))
# ('Brazil', 'Rio Claro', Decimal('103.73'))
# ('Puerto Rico', 'Ponce', Decimal('103.73'))
# ('Angola', 'Namibe', Decimal('103.73'))
# ('India', 'Yamuna Nagar', Decimal('103.72'))
# ('Brazil', 'Vitória de Santo Antão', Decimal('103.72'))
# ('Russian Federation', 'Jelets', Decimal('102.76'))
# ('Argentina', 'Escobar', Decimal('102.74'))
# ('India', 'Adoni', Decimal('101.78'))
# ('Turkey', 'Gaziantep', Decimal('101.78'))
# ('India', 'Rajkot', Decimal('101.78'))
# ('South Africa', 'Springs', Decimal('101.75'))
# ('Nigeria', 'Ondo', Decimal('101.75'))
# ('Argentina', 'Almirante Brown', Decimal('101.75'))
# ('Argentina', 'Vicente López', Decimal('101.74'))
# ('Finland', 'Oulu', Decimal('101.74'))
# ('Japan', 'Tama', Decimal('101.74'))
# ('Congo, The Democratic Republic of the', 'Lubumbashi', Decimal('101.74'))
# ('India', 'Chapra', Decimal('100.80'))
# ('Russian Federation', 'Balašiha', Decimal('100.78'))
# ('Russian Federation', 'Ivanovo', Decimal('100.77'))
# ('India', 'Varanasi (Benares)', Decimal('100.76'))
# ('Senegal', 'Ziguinchor', Decimal('100.75'))
# ('Yemen', 'Sanaa', Decimal('100.74'))
# ('Netherlands', 'Emmen', Decimal('100.74'))
# ('Brazil', 'Araçatuba', Decimal('100.72'))
# ('Cameroon', 'Yaoundé', Decimal('100.69'))
# ('China', 'Daxian', Decimal('100.67'))
# ('Iran', 'Sirjan', Decimal('99.80'))
# ('Japan', 'Okayama', Decimal('99.79'))
# ('China', 'Xi´angtan', Decimal('99.78'))
# ('India', 'Firozabad', Decimal('99.77'))
# ('Cameroon', 'Bamenda', Decimal('99.77'))
# ('Dominican Republic', 'La Romana', Decimal('99.77'))
# ('Japan', 'Kanazawa', Decimal('99.77'))
# ('French Polynesia', 'Faaa', Decimal('99.76'))
# ('China', 'Suihua', Decimal('99.76'))
# ('Iran', 'Esfahan', Decimal('99.75'))
# ('Peru', 'Sullana', Decimal('99.75'))
# ('Mexico', 'Monclova', Decimal('99.74'))
# ('Philippines', 'Iligan', Decimal('99.73'))
# ('Philippines', 'Taguig', Decimal('99.70'))
# ('China', 'Yantai', Decimal('98.80'))
# ('Russian Federation', 'Elista', Decimal('98.79'))
# ('Brazil', 'São Leopoldo', Decimal('98.78'))
# ('Brazil', 'São Bernardo do Campo', Decimal('98.78'))
# ('Colombia', 'Pereira', Decimal('98.77'))
# ('India', 'Sambhal', Decimal('98.77'))
# ('India', 'Allappuzha (Alleppey)', Decimal('98.76'))
# ('India', 'Jaipur', Decimal('98.75'))
# ('Japan', 'Higashiosaka', Decimal('98.75'))
# ('Cambodia', 'Battambang', Decimal('98.74'))
# ('Mexico', 'Torreón', Decimal('98.73'))
# ('Brazil', 'Ibirité', Decimal('97.80'))
# ('Philippines', 'Talavera', Decimal('97.79'))
# ('Taiwan', 'Chiayi', Decimal('97.76'))
# ('Venezuela', 'Caracas', Decimal('97.74'))
# ('United States', 'Compton', Decimal('97.74'))
# ('China', 'Laohekou', Decimal('97.74'))
# ('Oman', 'Salala', Decimal('97.73'))
# ('Philippines', 'Gingoog', Decimal('97.72'))
# ('Mexico', 'Carmen', Decimal('96.78'))
# ('Saudi Arabia', 'Abha', Decimal('96.76'))
# ('Algeria', 'Béchar', Decimal('96.75'))
# ('Saint Vincent and the Grenadines', 'Kingstown', Decimal('96.75'))
# ('Brazil', 'Alvorada', Decimal('96.74'))
# ('United States', 'Garland', Decimal('96.73'))
# ('Greece', 'Patras', Decimal('96.72'))
# ('China', 'Pingxiang', Decimal('95.78'))
# ('Canada', 'Gatineau', Decimal('95.78'))
# ('Mexico', 'La Paz', Decimal('95.78'))
# ('China', 'Nanyang', Decimal('95.77'))
# ('Brazil', 'Aparecida de Goiânia', Decimal('95.77'))
# ('United States', 'Roanoke', Decimal('95.77'))
# ('Mexico', 'Guadalajara', Decimal('95.77'))
# ('Bolivia', 'Sucre', Decimal('95.77'))
# ('Argentina', 'Córdoba', Decimal('95.75'))
# ('Nigeria', 'Zaria', Decimal('95.75'))
# ('Turkey', 'Eskisehir', Decimal('95.75'))
# ('South Africa', 'Botshabelo', Decimal('95.72'))
# ('Indonesia', 'Pangkal Pinang', Decimal('94.82'))
# ('India', 'Shimoga', Decimal('94.79'))
# ('India', 'Shivapuri', Decimal('94.78'))
# ('Egypt', 'Qalyub', Decimal('94.77'))
# ('Indonesia', 'Jakarta', Decimal('94.76'))
# ('United Kingdom', 'Dundee', Decimal('94.74'))
# ('Madagascar', 'Mahajanga', Decimal('93.78'))
# ('Canada', 'Oshawa', Decimal('93.78'))
# ('Vietnam', 'Vinh', Decimal('93.78'))
# ('Netherlands', 'Amersfoort', Decimal('93.77'))
# ('Brazil', 'Águas Lindas de Goiás', Decimal('93.76'))
# ('Brazil', 'Anápolis', Decimal('93.75'))
# ('Colombia', 'Buenaventura', Decimal('93.75'))
# ('Iran', 'Kermanshah', Decimal('93.74'))
# ('United States', 'Laredo', Decimal('93.72'))
# ('Venezuela', 'Ocumare del Tuy', Decimal('92.79'))
# ('Russian Federation', 'Kaliningrad', Decimal('92.79'))
# ('New Zealand', 'Hamilton', Decimal('92.76'))
# ('France', 'Toulon', Decimal('92.76'))
# ('Philippines', 'Bayugan', Decimal('92.75'))
# ('Iran', 'Arak', Decimal('92.73'))
# ('China', 'Laiwu', Decimal('92.73'))
# ('Cambodia', 'Phnom Penh', Decimal('92.73'))
# ('United States', 'Bellevue', Decimal('91.80'))
# ('Italy', 'Alessandria', Decimal('91.79'))
# ('Russian Federation', 'Jaroslavl', Decimal('91.79'))
# ('Pakistan', 'Okara', Decimal('91.79'))
# ('Nigeria', 'Kaduna', Decimal('91.78'))
# ('Brazil', 'Brasília', Decimal('91.78'))
# ('China', 'Zalantun', Decimal('91.77'))
# ('Ethiopia', 'Addis Abeba', Decimal('91.77'))
# ('South Korea', 'Kimchon', Decimal('91.76'))
# ('United States', 'Manchester', Decimal('91.76'))
# ('China', 'Xintai', Decimal('91.76'))
# ('China', 'Junan', Decimal('91.75'))
# ('Canada', 'Halifax', Decimal('91.75'))
# ('India', 'Balurghat', Decimal('91.74'))
# ('Bulgaria', 'Stara Zagora', Decimal('91.74'))
# ('Mexico', 'Nezahualcóyotl', Decimal('91.70'))
# ('China', 'Haining', Decimal('90.79'))
# ('Venezuela', 'Valencia', Decimal('90.78'))
# ('Netherlands', '´s-Hertogenbosch', Decimal('90.77'))
# ('Indonesia', 'Ciparay', Decimal('90.77'))
# ('Poland', 'Lublin', Decimal('89.79'))
# ('Ukraine', 'Konotop', Decimal('89.79'))
# ('Turkey', 'Kilis', Decimal('89.78'))
# ('Oman', 'Masqat', Decimal('89.77'))
# ('Egypt', 'Idfu', Decimal('89.77'))
# ('China', 'Ezhou', Decimal('89.77'))
# ('Japan', 'Kurashiki', Decimal('89.76'))
# ('Russian Federation', 'Zeleznogorsk', Decimal('89.76'))
# ('China', 'Huai´an', Decimal('89.75'))
# ('India', 'Katihar', Decimal('89.75'))
# ('Slovakia', 'Bratislava', Decimal('89.74'))
# ('Indonesia', 'Surakarta', Decimal('89.74'))
# ('Turkey', 'Denizli', Decimal('88.82'))
# ('Indonesia', 'Gorontalo', Decimal('88.80'))
# ('China', 'Rizhao', Decimal('88.79'))
# ('India', 'Dhule (Dhulia)', Decimal('88.78'))
# ('India', 'Amroha', Decimal('88.76'))
# ('Mexico', 'Juárez', Decimal('88.75'))
# ('Turkey', 'Inegöl', Decimal('88.74'))
# ('Japan', 'Hino', Decimal('87.82'))
# ('Indonesia', 'Purwakarta', Decimal('87.81'))
# ('South Korea', 'Cheju', Decimal('87.79'))
# ('Paraguay', 'Asunción', Decimal('87.79'))
# ('United Kingdom', 'Bradford', Decimal('87.77'))
# ('Germany', 'Saarbrücken', Decimal('87.76'))
# ('Bolivia', 'El Alto', Decimal('87.76'))
# ('Germany', 'Siegen', Decimal('86.81'))
# ('Israel', 'Ashqelon', Decimal('86.81'))
# ('China', 'Hami', Decimal('86.79'))
# ('China', 'Korla', Decimal('86.72'))
# ('Russian Federation', 'Serpuhov', Decimal('85.80'))
# ('India', 'Hoshiarpur', Decimal('85.79'))
# ('Israel', 'Bat Yam', Decimal('84.83'))
# ('Japan', 'Kamakura', Decimal('84.78'))
# ('Spain', 'Gijón', Decimal('84.78'))
# ('United States', 'Saint Louis', Decimal('84.77'))
# ('Iran', 'Shahr-e Kord', Decimal('84.77'))
# ('United States', 'Clarksville', Decimal('83.82'))
# ('China', 'Tieli', Decimal('83.81'))
# ('India', 'Nagaon', Decimal('83.79'))
# ('United Kingdom', 'Southport', Decimal('83.79'))
# ('Switzerland', 'Lausanne', Decimal('83.78'))
# ('United States', 'Grand Prairie', Decimal('82.79'))
# ('Morocco', 'Beni-Mellal', Decimal('82.78'))
# ('Argentina', 'San Miguel de Tucumán', Decimal('82.76'))
# ('Myanmar', 'Myingyan', Decimal('81.78'))
# ('Belarus', 'Mogiljov', Decimal('81.76'))
# ('Pakistan', 'Mandi Bahauddin', Decimal('80.83'))
# ('Saudi Arabia', 'al-Hawiya', Decimal('80.82'))
# ('Paraguay', 'Ciudad del Este', Decimal('80.82'))
# ('India', 'Ranchi', Decimal('80.79'))
# ('China', 'Yingkou', Decimal('80.77'))
# ('Mexico', 'Valle de Santiago', Decimal('80.76'))
# ('Indonesia', 'Cianjur', Decimal('80.74'))
# ('Philippines', 'Tarlac', Decimal('79.81'))
# ('France', 'Brest', Decimal('79.80'))
# ('Philippines', 'Bislig', Decimal('79.79'))
# ('United States', 'El Monte', Decimal('79.79'))
# ('Russian Federation', 'Dzerzinsk', Decimal('79.78'))
# ('Brazil', 'Bagé', Decimal('78.84'))
# ('Russian Federation', 'Syktyvkar', Decimal('78.80'))
# ('Tunisia', 'Sousse', Decimal('78.77'))
# ('India', 'Pathankot', Decimal('77.82'))
# ('Spain', 'Santiago de Compostela', Decimal('77.80'))
# ('Kazakstan', 'Pavlodar', Decimal('77.77'))
# ('Russian Federation', 'Niznekamsk', Decimal('76.83'))
# ('India', 'Jodhpur', Decimal('76.78'))
# ('Brazil', 'Luziânia', Decimal('76.77'))
# ('Argentina', 'Ezeiza', Decimal('76.77'))
# ('India', 'Berhampore (Baharampur)', Decimal('75.79'))
# ('South Africa', 'Chatsworth', Decimal('74.83'))
# ('Italy', 'Udine', Decimal('74.81'))
# ('Russian Federation', 'Novotšerkassk', Decimal('74.80'))
# ('China', 'Zaoyang', Decimal('74.78'))
# ('Chile', 'Rancagua', Decimal('73.84'))
# ('Turkey', 'Kütahya', Decimal('73.82'))
# ('Tonga', 'Nuku´alofa', Decimal('73.82'))
# ('Nigeria', 'Oyo', Decimal('73.80'))
# ('Japan', 'Koriyama', Decimal('73.79'))
# ('Russian Federation', 'Tšeboksary', Decimal('73.77'))
# ('Lithuania', 'Vilnius', Decimal('73.76'))
# ('Mexico', 'Pachuca de Soto', Decimal('72.82'))
# ('Japan', 'Matsue', Decimal('72.80'))
# ('India', 'Gandhinagar', Decimal('71.81'))
# ('China', 'Shenzhen', Decimal('71.81'))
# ('France', 'Le Mans', Decimal('71.80'))
# ('American Samoa', 'Tafuna', Decimal('71.80'))
# ('Mexico', 'Matamoros', Decimal('71.77'))
# ('Philippines', 'Hagonoy', Decimal('70.82'))
# ('India', 'Gulbarga', Decimal('70.81'))
# ('Mexico', 'Zapopan', Decimal('69.83'))
# ('India', 'Kumbakonam', Decimal('68.82'))
# ('Austria', 'Linz', Decimal('68.79'))
# ('Afghanistan', 'Kabul', Decimal('67.82'))
# ('Turkey', 'Tarsus', Decimal('66.84'))
# ('Indonesia', 'Tegal', Decimal('66.81'))
# ('Venezuela', 'Barcelona', Decimal('66.79'))
# ('India', 'Kanchrapara', Decimal('65.84'))
# ('Taiwan', 'Tsaotun', Decimal('64.81'))
# ('India', 'Hubli-Dharwad', Decimal('62.85'))
# ('China', 'Enshi', Decimal('59.86'))
# ('Switzerland', 'Basel', Decimal('58.86'))
# ('Mozambique', 'Tete', Decimal('58.82'))
# ('Sudan', 'al-Qadarif', Decimal('57.81'))
# ('Poland', 'Bydgoszcz', Decimal('52.88'))
# ('China', 'Fuzhou', Decimal('50.86'))
# ('United States', 'Tallahassee', Decimal('50.85'))

# %% [markdown]
# ### Close cursor

# %%
db_cursor.close()
# Out:
# True
